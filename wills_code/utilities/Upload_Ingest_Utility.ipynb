# %% [markdown]
# ## Utilities to Upload, Ingest and Verify Logfiles From SSDs to s3 to Aletheia

# %%
import boto3
import requests
import json
import os
import argparse
import pandas as pd
import time

import numpy as np
from datetime import datetime 
#from brtdevkit.ml import Workflow
import pytz

#from brtdevkit.ml import Workflow
from brtdevkit.ml.core import KubeflowPipeline, KubeflowPipelineRun

image_ingestion_pipeline = None
isp_target_rom = '07090103'

utc = pytz.UTC

from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### To Complete the Process of Getting Logfiles On an SSD into Images in Aletheia:</br>
# * Upload the SSD to AWS via the AWS CLI
# * Verify the Upload
# * Kick off ingestion workflows (will typically take several hours including ISP processing)
# * Verify Ingestion
# </br>
#
# #### Outside of This Loop for SSDs, Verify That All Logs Collected to Date Have Been Ingested Into Aletheia

# %% [markdown]
# ### Functions to Carry Out Each Step

# %%
# Initialize s3 and set environment variables
import time
s3 = boto3.client('s3')
image_ingestion_experiment_name = 'shasta_image_ingest'
image_ingestion_pipeline_name = 'Shasta Image Data Processor'
image_ingestion_pipeline = None

def get_logfile_directories(bucket, prefix, just_fsize =False):
    """
    Finds S3 directories with flatbuffer logfiles in them.
    :param bucket: S3 bucket to search in
    :param prefix: the prefix (pathname) underneath the bucket to be searched
    """

    s3 = boto3.client('s3')

    dir_list = []
    fsize = 0
    kwargs = {'Bucket': bucket, 'Prefix': prefix}
    while True:
        resp = s3.list_objects_v2(MaxKeys =10000, **kwargs)
        
        # This bit of code handles pagination in the boto library.
        if 'Contents' in resp:
            for entry in resp['Contents']:
                if entry['Key'].endswith('.bfbs'):
                    dir_list.append(os.path.dirname(entry['Key']))
                    fsize += entry['Size']
            try:
                kwargs['ContinuationToken'] = resp['NextContinuationToken']
            except KeyError:
                break
        else:
            break
    if just_fsize == True:
        return fsize
    else:
        return dir_list, fsize

def get_SSD_file_size(start_path):
    """
    Given a path to an SSD, get the size of the files. 
    """
    
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            # skip if it is symbolic link
            if not os.path.islink(fp):
                total_size += os.path.getsize(fp)

    return total_size

def check_upload_complete(bucket, prefix, SSD_path):
    """
    Given a bucket and prefix in S3, as well as the path to the SSD from my laptop
    Verify that eveything on the SSD was in fact uploaded to S3. 
    
    ** TESTED: Works great for DCM logs. Probably not for machines with all their VPUs.
    """
    
    # Retrieve all log file names on the SSD
    SSD_dirs = []
    for f in os.listdir(SSD_path):
        li = os.listdir(SSD_path + f)
        SSD_dirs.append(prefix  +f)

    # Retrieve all logfile names in S3
    s3_dirs, fsize = get_logfile_directories(bucket = bucket, prefix = prefix)
    s3_dirs = set(s3_dirs)

    print(f'There are {len(SSD_dirs)} logfiles on the SSD and {len(s3_dirs)} in s3.')
    
    # Check SSD against S3
    s3_fsize = 0
    for n in np.unique(SSD_dirs):
        if n in s3_dirs:
            fsize = get_logfile_directories(bucket = bucket, prefix = n, just_fsize=True)
            s3_fsize = s3_fsize + fsize
    
    # Compare filesizes
    s3_size = s3_fsize/1000000
    SSD_fsize = get_SSD_file_size(SSD_path)/1000000
    equal_fsize = abs(SSD_fsize - s3_size) < 1000
    
    # Compare logs
    all_logs_in_s3 = set(SSD_dirs).discard(set(s3_dirs)) == None
    
    if all_logs_in_s3 and equal_fsize:
        print(f'File size of {s3_size:.0f} MB confirmed')
        print('All files on drive accounted for in S3.')
        #return dirs, s3_size
    elif all_logs_in_s3:
        print(f'Could not verify filesize. There is a discepancy of {SSD_fsize - s3_size} out of {SSD_fsize}. Check paths')
    
    else:
        print('Upload looks strange. Verify path.')
        return set(SSD_dirs).discard(set(s3_dirs)), s3_size

def submit_image_ingestion_workflow(bucket, s3_key, retry=50):
    """
    Wrapper around the brtdevkit image ingestion pipeline object that is error tolerant.
    :param bucket: S3 bucket name
    :param s3_key: s3 key of object to be processed
    :param retry: number of times to retry the worflow submission in case of failure
    :return: tuple of pipeline id and s3_key
    """

    global image_ingestion_pipeline  # NOQA. Use a global so we only have to set this var once and
                                     # can run tests importing this file without retrieving the pipeline.
                                     # TODO: Encapsulate in a class.
    if not image_ingestion_pipeline:
        image_ingestion_pipeline = KubeflowPipeline.retrieve(name=image_ingestion_pipeline_name)
    for i in range(retry):
        try:
            now = datetime.now().strftime("%d %B %Y %I:%M:%S %p")
            run = image_ingestion_pipeline.submit(
                job_name=f'Run of {image_ingestion_pipeline.name} at {now}',
                experiment_name=image_ingestion_experiment_name,
                params={
                    's3_bucket': bucket,
                    's3_key': s3_key,
                    'optional_args': '-u'
                    #'optional_args':{'camer'}
                })
        except Exception as e:
            print(f'Attempt {i+1}: error encountered while processing {s3_key}, retrying...')
            print(e)
            time.sleep(5)
            continue
        break
    run_id = run['id']
    print(f"launched image ingestion pipeline {run_id} on key {s3_key}")
    return run_id, s3_key

def ingest_new_SSD_logs(SSD_path, dcm):
    """
    Given a list of logfiles in S3, launch ingestion workflows for those S3 logfiles. 
    """
    SSD_dirs = []
    for f in os.listdir(SSD_path):
        li = os.listdir(SSD_path + f)
        SSD_dirs.append(prefix +f)
    print(f'There are {len(SSD_dirs)} logs to ingest.') 
    for i in SSD_dirs[0:5]:
        submit_image_ingestion_workflow('brt-dcm-data', dcm + '/0/full/' +i)
        time.sleep(30)
        
def verify_ingest(df, in_s3):
    """
    Given a dataframe of all DCM images from 2021, and a list of logfiels in S3, find the difference between the two.
    These will be the logfiles we still need to ingest. 
    """
    # Check which s3_paths are present in Aletheia (2021 data only)
    paths = list(df.s3_path.unique())
    in_db = set([p.split('s3://brt-dcm-data/')[1] for p in paths])
    missing = list(in_s3.difference(in_db))
    print(f'There are {len(missing)} s3 logs not accounted for in Aletheia.')
    return sorted(missing)

# %%
bucket = 'brt-dcm-data'
prefix = 'porpoise-sysbox1/0/full/'
d, f = get_logfile_directories(bucket, prefix)
print(len(d))
d[0:5]
# Out:
# 3364
# ['porpoise-sysbox1/0/full/2018-01-28_15-59-09.238302761',
#  'porpoise-sysbox1/0/full/2018-01-28_15-59-09.238302761',
#  'porpoise-sysbox1/0/full/2018-01-28_15-59-09.238302761',
#  'porpoise-sysbox1/0/full/2018-01-28_15-59-09.238302761',
#  'porpoise-sysbox1/0/full/2018-01-28_15-59-18.355660711']

# %%
new_logs = []

for m in d:
    #print(m[32:34])
    if (m[24:32] == '2021-04-') and (int(m[32:34]) > 16):
        new_logs.append(m)
        
nl = np.unique(new_logs)

# %%
import time

def submit_image_ingestion_workflow(bucket, s3_key, retry=50):
    """
    Wrapper around the brtdevkit image ingestion pipeline object that is error tolerant.
    :param bucket: S3 bucket name
    :param s3_key: s3 key of object to be processed
    :param retry: number of times to retry the worflow submission in case of failure
    :return: tuple of pipeline id and s3_key
    """

    global image_ingestion_pipeline  # NOQA. Use a global so we only have to set this var once and
                                     # can run tests importing this file without retrieving the pipeline.
                                     # TODO: Encapsulate in a class.
    if not image_ingestion_pipeline:
        image_ingestion_pipeline = KubeflowPipeline.retrieve(name=image_ingestion_pipeline_name)
    for i in range(retry):
        try:
            now = datetime.now().strftime("%d %B %Y %I:%M:%S %p")
            run = image_ingestion_pipeline.submit(
                job_name=f'Run of {image_ingestion_pipeline.name} at {now}',
                experiment_name=image_ingestion_experiment_name,
                params={
                    's3_bucket': bucket,
                    's3_key': s3_key,
                    'optional_args': '-u'
                })
        except Exception as e:
            print(f'Attempt {i+1}: error encountered while processing {s3_key}, retrying...')
            print(e)
            time.sleep(5)
            continue
        break
    run_id = run['id']
    print(f"launched image ingestion pipeline {run_id} on key {s3_key}")
    return run_id, s3_key

for i in nl[5:]:
    submit_image_ingestion_workflow(bucket='brt-dcm-data', s3_key = i)
    time.sleep(30)
# Out:
# launched image ingestion pipeline b78d5a46-1215-4b67-a03a-9879dbace002 on key porpoise-sysbox1/0/full/2021-04-20_14-56-14.874151309
# launched image ingestion pipeline 5133a244-6a5f-419e-ab69-bb37e7979945 on key porpoise-sysbox1/0/full/2021-04-20_15-01-19.445722962
# launched image ingestion pipeline ffea8990-afb8-41e6-9062-c3e82e951b36 on key porpoise-sysbox1/0/full/2021-04-20_15-03-57.144754216
# launched image ingestion pipeline 88382aeb-56e9-4917-a6b9-a9220d6ab049 on key porpoise-sysbox1/0/full/2021-04-20_15-13-57.877413844
# launched image ingestion pipeline 854ae98b-07b1-4483-81d9-f58b970fa7cc on key porpoise-sysbox1/0/full/2021-04-20_15-19-00.285750208
# launched image ingestion pipeline 35db1d27-6995-439c-9cf5-0686d014a909 on key porpoise-sysbox1/0/full/2021-04-20_15-22-28.231276854
# launched image ingestion pipeline 6c1cced6-d44b-46e9-a73b-74f73a10c0f5 on key porpoise-sysbox1/0/full/2021-04-20_15-25-40.097126456
# launched image ingestion pipeline 9a9a1a7d-efbd-405e-8360-531bcdc14a0e on key porpoise-sysbox1/0/full/2021-04-20_15-29-02.022061641
# launched image ingestion pipeline f9b520ff-57f1-4887-a874-a7b36cf16b42 on key porpoise-sysbox1/0/full/2021-04-20_15-35-38.895866306
# launched image ingestion pipeline c0b26f4c-df1c-4e03-9035-748cf866295b on key porpoise-sysbox1/0/full/2021-04-20_15-39-39.986590150
# launched image ingestion pipeline 0c004b48-5980-4526-9f54-dd58ca0d00ad on key porpoise-sysbox1/0/full/2021-04-20_15-43-30.035115121
# launched image ingestion pipeline f054e54f-9643-45e7-aec1-609e1b98c4e5 on key porpoise-sysbox1/0/full/2021-04-20_15-46-28.846467587
# launched image ingestion pipeline cdc8a991-c873-45e2-ab51-d449b0bad7c8 on key porpoise-sysbox1/0/full/2021-04-20_17-49-01.014558420
# launched image ingestion pipeline 6ddd446e-0f17-4f57-9945-dd24ed733e55 on key porpoise-sysbox1/0/full/2021-04-20_17-52-19.942096433
# launched image ingestion pipeline 8b9b2ae0-03c2-433e-bc18-561715ab5f4c on key porpoise-sysbox1/0/full/2021-04-20_17-56-46.186674918
# launched image ingestion pipeline 0121fb28-092c-4734-9513-0307c7e4e1ee on key porpoise-sysbox1/0/full/2021-04-20_17-59-30.967167712
# launched image ingestion pipeline 3a16039d-2814-4e9e-a040-191f281ee249 on key porpoise-sysbox1/0/full/2021-04-20_18-08-10.456102289
# launched image ingestion pipeline 6b792bf1-135c-4006-b8c0-a4421612144a on key porpoise-sysbox1/0/full/2021-04-20_18-11-54.522679602
# launched image ingestion pipeline 9f2b468d-c3e6-4a6b-a7b7-e382e9292f2c on key porpoise-sysbox1/0/full/2021-04-20_18-18-49.484409744
# launched image ingestion pipeline 0599e510-1203-4688-8f92-f927a927c82b on key porpoise-sysbox1/0/full/2021-04-20_18-22-29.504563973
# launched image ingestion pipeline 6b210daa-a869-4153-b0f0-c8fc90357001 on key porpoise-sysbox1/0/full/2021-04-20_18-30-45.808206174
# launched image ingestion pipeline ea208154-799e-42ff-ba76-ea46553f4377 on key porpoise-sysbox1/0/full/2021-04-20_18-33-15.521375442
# launched image ingestion pipeline b52cce10-7ddf-4973-b887-6eae5c25b60f on key porpoise-sysbox1/0/full/2021-04-20_18-47-50.670488967
# launched image ingestion pipeline 8ed65522-1473-4877-978d-fa53c77669f3 on key porpoise-sysbox1/0/full/2021-04-20_18-51-18.641537645
# launched image ingestion pipeline 23c6e720-08ad-4bc2-80c7-91b62df910b4 on key porpoise-sysbox1/0/full/2021-04-20_18-54-50.656828995
# launched image ingestion pipeline 24578203-5243-4e52-8888-0c6e32af0049 on key porpoise-sysbox1/0/full/2021-04-20_18-59-34.996331371
# launched image ingestion pipeline 7170a4f1-857d-4c67-90b5-13251dacbd22 on key porpoise-sysbox1/0/full/2021-04-20_19-06-56.053089101
# launched image ingestion pipeline 6531f9b5-130a-4183-857a-2f7ab50ae3e5 on key porpoise-sysbox1/0/full/2021-04-20_19-11-41.369032643
# launched image ingestion pipeline 727185b7-da0c-4503-9e05-a8c88ff94524 on key porpoise-sysbox1/0/full/2021-04-20_19-15-46.508947760
# launched image ingestion pipeline 3ea3f965-3ebc-4778-87d5-566d6ee9b9db on key porpoise-sysbox1/0/full/2021-04-20_19-19-14.466593178
# launched image ingestion pipeline 3ed9039d-b696-4365-89b2-f4d0be6531e9 on key porpoise-sysbox1/0/full/2021-04-20_19-26-10.425563016
# launched image ingestion pipeline 7ae2714d-7105-4c95-8cd6-e5122565da37 on key porpoise-sysbox1/0/full/2021-04-20_19-29-29.349635711
# launched image ingestion pipeline 4d3814ff-e238-4e92-9692-43ff362ce958 on key porpoise-sysbox1/0/full/2021-04-20_19-32-40.264276723
# launched image ingestion pipeline 07572556-ed6d-4fef-a1a2-c7e9d11f20e9 on key porpoise-sysbox1/0/full/2021-04-20_19-39-52.313864901
# launched image ingestion pipeline 2ab40ed5-b228-460c-b692-65b5f381f5cc on key porpoise-sysbox1/0/full/2021-04-20_19-45-05.799852559
# launched image ingestion pipeline ec0906fe-055c-4615-992d-bc9f40ffb780 on key porpoise-sysbox1/0/full/2021-04-20_19-45-31.921068872
# launched image ingestion pipeline 927ed68a-7344-4748-8e93-b82816eb9807 on key porpoise-sysbox1/0/full/2021-04-20_19-50-21.319065243
# launched image ingestion pipeline 5f7771fa-00af-47d6-ae44-5ad165e8098c on key porpoise-sysbox1/0/full/2021-04-20_19-56-51.204794720
# launched image ingestion pipeline f4d94248-6663-47ad-8cbf-58db2de538e4 on key porpoise-sysbox1/0/full/2021-04-20_20-04-27.375848543
# launched image ingestion pipeline a4441d69-cf88-45e7-ae07-e40a061f2a08 on key porpoise-sysbox1/0/full/2021-04-20_20-07-58.343529740
# launched image ingestion pipeline 8d4ba7ab-2642-4817-80d0-4c9b45366877 on key porpoise-sysbox1/0/full/2021-04-20_20-11-13.237033248

# %% [markdown]
# ### With the SSD Still Plugged in, Verify Upload and Ingest

# %%
# Check To See if All Files Have Been uploaded from a SSD

def check_upload_complete(bucket, prefix, SSD_path):
    """
    Given a bucket and prefix in S3, as well as the path to the SSD from my laptop
    Verify that eveything on the SSD was in fact uploaded to S3. 
    
    ** TESTED: Works great for DCM logs. Probably not for machines with all their VPUs.
    """
    
    # Retrieve all log file names on the SSD
    SSD_dirs = []
    for f in os.listdir(SSD_path):
        li = os.listdir(SSD_path + f)
        SSD_dirs.append(prefix  + 'vpu0-0a/full/' +f)

    # Retrieve all logfile names in S3
    s3_dirs, fsize = get_logfile_directories(bucket = bucket, prefix = prefix)
    s3_dirs = set(s3_dirs)

    print(f'There are {len(SSD_dirs)} logfiles on the SSD and {len(s3_dirs)} in s3.')
    
    # Check SSD against S3
    s3_fsize = 0
    for n in np.unique(SSD_dirs):
        if n in s3_dirs:
            fsize = get_logfile_directories(bucket = bucket, prefix = n, just_fsize=True)
            s3_fsize = s3_fsize + fsize
    
    # Compare filesizes
    s3_size = s3_fsize/1000000
    SSD_fsize = get_SSD_file_size(SSD_path)/1000000
    equal_fsize = abs(SSD_fsize - s3_size) < 1000
    
    # Compare logs
    all_logs_in_s3 = set(SSD_dirs).discard(set(s3_dirs)) == None
    
    if all_logs_in_s3 and equal_fsize:
        print(f'File size of {s3_size:.0f} MB confirmed')
        print('All files on drive accounted for in S3.')
        #return dirs, s3_size
    elif all_logs_in_s3:
        print(f'Could not verify filesize. There is a discepancy of {SSD_fsize - s3_size} out of {SSD_fsize}. Check paths')
    
    else:
        print('Upload looks strange. Verify path.')
        return set(SSD_dirs).discard(set(s3_dirs)), s3_size

bucket = 'brt-dcm-data'
prefix = 'dcm18/'
SSD_path ='/media/williamroberts/SSD223/dcm18-sysbox1/vpu0-0a/full/'

check_upload_complete(bucket , prefix , SSD_path )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-f63b2d2a98a8> in <module>
#      51 SSD_path ='/media/williamroberts/SSD223/dcm18-sysbox1/vpu0-0a/full/'
#      52
# ---> 53 check_upload_complete(bucket , prefix , SSD_path )
#
# <ipython-input-55-f63b2d2a98a8> in check_upload_complete(bucket, prefix, SSD_path)
#      16
#      17     # Retrieve all logfile names in S3
# ---> 18     s3_dirs, fsize = get_logfile_directories(bucket = bucket, prefix = prefix)
#      19     s3_dirs = set(s3_dirs)
#      20
#
# <ipython-input-2-d8bf18edbb98> in get_logfile_directories(bucket, prefix, just_fsize)
#      19     kwargs = {'Bucket': bucket, 'Prefix': prefix}
#      20     while True:
# ---> 21         resp = s3.list_objects_v2(MaxKeys =10000, **kwargs)
#      22
#      23         # This bit of code handles pagination in the boto library.
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     646         else:
#     647             http, parsed_response = self._make_request(
# --> 648                 operation_model, request_dict, request_context)
#     649
#     650         self.meta.events.emit(
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     665     def _make_request(self, operation_model, request_dict, request_context):
#     666         try:
# --> 667             return self._endpoint.make_request(operation_model, request_dict)
#     668         except Exception as e:
#     669             self.meta.events.emit(
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
# --> 135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#     137                                 success_response, exception):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     165         # If no exception occurs then exception is None.
#     166         success_response, exception = self._do_get_response(
# --> 167             request, operation_model)
#     168         kwargs_to_emit = {
#     169             'response_dict': None,
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     216         parser = self._response_parser_factory.create_parser(protocol)
#     217         parsed_response = parser.parse(
# --> 218             response_dict, operation_model.output_shape)
#     219         history_recorder.record('PARSED_RESPONSE', parsed_response)
#     220         return (http_response, parsed_response), None
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in parse(self, response, shape)
#     240                 parsed = self._do_error_parse(response, shape)
#     241         else:
# --> 242             parsed = self._do_parse(response, shape)
#     243
#     244         # We don't want to decorate event stream responses with metadata
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _do_parse(self, response, shape)
#     773         self._parse_non_payload_attrs(response, shape,
#     774                                       member_shapes, final_parsed)
# --> 775         self._parse_payload(response, shape, member_shapes, final_parsed)
#     776         return final_parsed
#     777
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _parse_payload(self, response, shape, member_shapes, final_parsed)
#     810         else:
#     811             original_parsed = self._initial_body_parse(response['body'])
# --> 812             body_parsed = self._parse_shape(shape, original_parsed)
#     813             final_parsed.update(body_parsed)
#     814
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     300         handler = getattr(self, '_handle_%s' % shape.type_name,
#     301                           self._default_handle)
# --> 302         return handler(shape, node)
#     303
#     304     def _handle_list(self, shape, node):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _handle_structure(self, shape, node)
#     375             if member_node is not None:
#     376                 parsed[member_name] = self._parse_shape(
# --> 377                     member_shape, member_node)
#     378             elif member_shape.serialization.get('xmlAttribute'):
#     379                 attribs = {}
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     300         handler = getattr(self, '_handle_%s' % shape.type_name,
#     301                           self._default_handle)
# --> 302         return handler(shape, node)
#     303
#     304     def _handle_list(self, shape, node):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _handle_list(self, shape, node)
#     358         if shape.serialization.get('flattened') and not isinstance(node, list):
#     359             node = [node]
# --> 360         return super(BaseXMLResponseParser, self)._handle_list(shape, node)
#     361
#     362     def _handle_structure(self, shape, node):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _handle_list(self, shape, node)
#     308         member_shape = shape.member
#     309         for item in node:
# --> 310             parsed.append(self._parse_shape(member_shape, item))
#     311         return parsed
#     312
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     300         handler = getattr(self, '_handle_%s' % shape.type_name,
#     301                           self._default_handle)
# --> 302         return handler(shape, node)
#     303
#     304     def _handle_list(self, shape, node):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _handle_structure(self, shape, node)
#     375             if member_node is not None:
#     376                 parsed[member_name] = self._parse_shape(
# --> 377                     member_shape, member_node)
#     378             elif member_shape.serialization.get('xmlAttribute'):
#     379                 attribs = {}
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _parse_shape(self, shape, node)
#     300         handler = getattr(self, '_handle_%s' % shape.type_name,
#     301                           self._default_handle)
# --> 302         return handler(shape, node)
#     303
#     304     def _handle_list(self, shape, node):
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _get_text_content(self, shape, node_or_string)
#     173         else:
#     174             text = node_or_string
# --> 175         return func(self, shape, text)
#     176     return _get_text_content
#     177
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/parsers.py in _handle_timestamp(self, shape, text)
#     460     @_text_content
#     461     def _handle_timestamp(self, shape, text):
# --> 462         return self._timestamp_parser(text)
#     463
#     464     @_text_content
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/botocore/utils.py in parse_timestamp(value)
#     566         # different time zone, so here we provide a context which will
#     567         # enforce that GMT == UTC.
# --> 568         return dateutil.parser.parse(value, tzinfos={'GMT': tzutc()})
#     569     except (TypeError, ValueError) as e:
#     570         raise ValueError('Invalid timestamp "%s": %s' % (value, e))
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     644                                                       second=0, microsecond=0)
#     645
# --> 646         res, skipped_tokens = self._parse(timestr, **kwargs)
#     647
#     648         if res is None:
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/dateutil/parser/_parser.py in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     744                 if value is not None:
#     745                     # Numeric token
# --> 746                     i = self._parse_numeric_token(l, i, info, ymd, res, fuzzy)
#     747
#     748                 # Check weekday
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/dateutil/parser/_parser.py in _parse_numeric_token(self, tokens, idx, info, ymd, res, fuzzy)
#     962                 if tokens[idx + 2].isdigit():
#     963                     # 01-01[-01]
# --> 964                     ymd.append(tokens[idx + 2])
#     965                 else:
#     966                     # 01-Jan[-01]
#
# ~/code/brtdevkit/venv/lib/python3.6/site-packages/dateutil/parser/_parser.py in append(self, val, label)
#     445             label = 'Y'
#     446
# --> 447         super(self.__class__, self).append(int(val))
#     448
#     449         if label == 'M':
#
# KeyboardInterrupt:

# %%
SSD_path = '/media/williamroberts/SSD209/dcm12-sysbox1/vpu0-0a/full/'

def ingest_new_SSD_logs(SSD_path, dcm, v='vpu0-0a'):
    """
    Given a list of logfiles in S3, launch ingestion workflows for those S3 logfiles. 
    """
    SSD_dirs = []
    for f in os.listdir(SSD_path):
        li = os.listdir(SSD_path + f)
        SSD_dirs.append(f)
    print(f'There are {len(SSD_dirs)} logs to ingest.') 
    for i in SSD_dirs:
        #print('brt-dcm-data', dcm + '/vpu0-0a/full/' +i)
        submit_image_ingestion_workflow('brt-dcm-data', dcm + '/'+ v +'/full/' +i)
        time.sleep(30)
        
vpus = ['vpu0-1a', 'vpu0-2a', 'vpu0-3a', 'vpu0-4a', 'vpu0-10a', 'vpu0-11a', 'vpu0-12a', 'vpu0-13a', 'vpu0-14a']

#for v in vpus:
    #ingest_new_SSD_logs('/media/williamroberts/SSD118/db4-sysbox1/' + v + '/full/', 'db8')
        
ingest_new_SSD_logs(SSD_path, 'dcm12') # Ingest after 130
# Out:
# There are 219 logs to ingest.
# launched image ingestion pipeline b5c77cc7-3000-4335-92a7-a99081e409f2 on key dcm12/vpu0-0a/full/2021-06-29_01-29-14.940401284_197_1818.335926628
# launched image ingestion pipeline b9690ebb-30d0-4c16-a229-57a0850ccbe3 on key dcm12/vpu0-0a/full/2021-07-06_16-04-58.677250304_221_793.701921197
# launched image ingestion pipeline d77a1ec7-738a-4fac-8493-b805cee31bdf on key dcm12/vpu0-0a/full/2021-07-06_16-39-30.602806674_221_2865.601380021
# launched image ingestion pipeline 9d809da1-9148-4054-9a98-32e08ee0e323 on key dcm12/vpu0-0a/full/2021-07-06_16-35-38.557842347_221_2633.556415470
# launched image ingestion pipeline 54312d35-acae-4f78-8276-fdce8e3ebab5 on key dcm12/vpu0-0a/full/2021-06-26_23-06-27.793663147_189_1158.997155979
# launched image ingestion pipeline 46452bc9-e653-43f5-a0bb-44098064e90b on key dcm12/vpu0-0a/full/2021-07-02_22-24-47.569261365_208_392.996689781
# launched image ingestion pipeline 4f845531-56b1-4e93-b5b3-82ec388bba67 on key dcm12/vpu0-0a/full/2021-07-06_02-11-18.227956080_219_2950.463915984
# launched image ingestion pipeline b53b7efc-3e88-4afb-beea-0039dc5c9380 on key dcm12/vpu0-0a/full/2021-07-02_21-34-49.374014636_207_1137.601592300
# launched image ingestion pipeline 147babd9-e1e2-4987-b835-59f39950d56d on key dcm12/vpu0-0a/full/2021-06-26_22-59-25.929115569_189_737.132608433
# launched image ingestion pipeline 61674afd-9515-4dea-b15e-c1c08e2b183d on key dcm12/vpu0-0a/full/2021-06-26_23-18-50.978158876_189_1902.181651644
# launched image ingestion pipeline 3d3e38a0-f747-4c1c-af8c-a635b3af3eb1 on key dcm12/vpu0-0a/full/2021-06-26_23-10-42.893576828_189_1414.097069564
# launched image ingestion pipeline 0c369560-d13e-4ac3-bed9-b7b038848e37 on key dcm12/vpu0-0a/full/2021-07-01_23-36-23.411589645_204_1796.846982380
# launched image ingestion pipeline f064b1da-790a-452e-9e26-a25d62704edf on key dcm12/vpu0-0a/full/2021-07-01_23-33-39.765327535_204_1633.200720527
# launched image ingestion pipeline 624bbf9a-cfb9-4860-baf4-a60bd705f640 on key dcm12/vpu0-0a/full/2021-07-03_19-43-14.865549092_214_746.983270740
# launched image ingestion pipeline 27861501-8913-4193-b7bf-e8fe31b3ee5e on key dcm12/vpu0-0a/full/2021-07-03_23-53-50.022695494_216_1464.291388838
# launched image ingestion pipeline 9093b645-4d43-4499-bf58-5b1827df81f9 on key dcm12/vpu0-0a/full/2021-06-29_01-39-55.478468369_197_2458.873993745
# launched image ingestion pipeline 6182f580-2759-489b-a63d-d7aaa9a347ed on key dcm12/vpu0-0a/full/2021-06-26_23-04-29.269942002_189_1040.473434674
# launched image ingestion pipeline 341d0e97-2731-40fa-9db7-3efdf6f1406c on key dcm12/vpu0-0a/full/2021-07-06_18-30-08.986738083_223_902.234963144
# launched image ingestion pipeline bb78b818-f266-441b-9bbc-3cae3c2a9471 on key dcm12/vpu0-0a/full/2021-06-28_22-56-17.098749608_195_1692.533132904
# launched image ingestion pipeline 49ba3bcc-79c3-49ed-a82e-7a324fc6be8d on key dcm12/vpu0-0a/full/2021-07-02_02-17-03.518701561_205_3433.684915097
# launched image ingestion pipeline 2a30c15d-72d4-42e5-acc8-123cc1818292 on key dcm12/vpu0-0a/full/2021-06-29_01-12-01.892402714_197_785.287927962
# launched image ingestion pipeline 0367d60f-28e9-4e7e-8643-b0a30622fecb on key dcm12/vpu0-0a/full/2021-07-06_18-19-34.224805062_223_267.475531405
# launched image ingestion pipeline 29ce786c-efec-4593-b04a-cb9007abc1ed on key dcm12/vpu0-0a/full/2021-06-26_23-26-08.827591034_189_2340.031083834
# launched image ingestion pipeline a0d2b42c-aa37-4ffd-b550-00903430219b on key dcm12/vpu0-0a/full/2021-07-03_19-59-32.809825410_214_1724.927546834
# launched image ingestion pipeline a2bca89d-73fb-488b-99ce-dd01144908d1 on key dcm12/vpu0-0a/full/2021-06-29_14-16-41.170780028_199_299.532294204
# launched image ingestion pipeline 0b919250-efa1-4892-b461-87e30e5dbb53 on key dcm12/vpu0-0a/full/2021-07-06_16-40-56.987165623_221_2951.985738842
# launched image ingestion pipeline 9124d1c9-1437-4b22-813b-2baedc74f9cb on key dcm12/vpu0-0a/full/2021-06-28_22-36-37.493741570_195_512.928124834
# launched image ingestion pipeline 2c9b85f6-c6cd-486d-9a21-242c1bf96feb on key dcm12/vpu0-0a/full/2021-06-29_01-24-37.853994493_197_1541.249519837
# launched image ingestion pipeline 7edf3354-82f3-4eaa-994b-e8afcc720d99 on key dcm12/vpu0-0a/full/2021-06-29_01-14-13.452269139_197_916.847794483
# launched image ingestion pipeline 4e9a37df-5db7-47a6-beae-4e6774366893 on key dcm12/vpu0-0a/full/2021-06-26_23-20-42.446289587_189_2013.649782099
# launched image ingestion pipeline ce60b145-3515-4a0c-9a50-a273dbe92dc0 on key dcm12/vpu0-0a/full/2021-07-01_23-24-04.343697417_204_1057.779090441
# launched image ingestion pipeline e7d48418-5a3e-41d7-a9ab-850b51ee4f73 on key dcm12/vpu0-0a/full/2021-07-03_20-01-17.275098546_214_1829.392820066
# launched image ingestion pipeline 25aa33fd-ee00-4609-a339-8051fb8cab03 on key dcm12/vpu0-0a/full/2021-07-03_19-54-22.555416321_214_1414.673137777
# launched image ingestion pipeline 4e192b8a-3f85-44a0-805f-525b4d19fa2f on key dcm12/vpu0-0a/full/2021-07-06_15-57-21.468143414_221_335.751714553
# launched image ingestion pipeline 65e5b8f2-a774-46e2-89e0-7c0cca58befd on key dcm12/vpu0-0a/full/2021-06-29_19-45-13.259018431_201_1345.647356895
# launched image ingestion pipeline 043755f1-9dab-4dc9-b3ed-9c40a62a6c94 on key dcm12/vpu0-0a/full/2021-07-02_02-27-28.149300777_205_4058.315514281
# launched image ingestion pipeline 939d7d5f-be9d-4078-ba5c-9fd4b1063cd1 on key dcm12/vpu0-0a/full/2021-06-26_21-59-35.183129862_188_1011.578436806
# launched image ingestion pipeline 6dd76b45-0389-46c7-8b79-69ecfa057ad5 on key dcm12/vpu0-0a/full/2021-07-06_18-24-19.410957012_223_552.659181849
# launched image ingestion pipeline b16a6b2f-ed19-4d60-938b-47203e2133ae on key dcm12/vpu0-0a/full/2021-07-03_21-04-40.218555356_215_1248.638592988
# launched image ingestion pipeline d02415c9-20f9-4c4f-b7df-f6379c81cb23 on key dcm12/vpu0-0a/full/2021-07-03_23-34-23.416683135_216_297.685376671
# launched image ingestion pipeline 3243ca86-d019-4fb0-9e9b-9d23e09ec053 on key dcm12/vpu0-0a/full/2021-07-03_21-07-34.988249978_215_1423.408287770
# launched image ingestion pipeline dbc2e511-b6ec-4c36-96eb-f5ca3726055c on key dcm12/vpu0-0a/full/2021-07-06_17-42-20.459251672_222_894.979859123
# launched image ingestion pipeline 91f4205d-dcf5-4242-9c5a-cdba3a620fa1 on key dcm12/vpu0-0a/full/2021-06-29_01-09-56.368232626_197_659.763758066
# launched image ingestion pipeline fc5c8d5c-7a25-45ce-b6e9-9b5d27606569 on key dcm12/vpu0-0a/full/2021-07-03_23-42-21.256029906_216_775.524723410
# launched image ingestion pipeline eb37d961-2ac0-41c5-a60a-81416b1de36f on key dcm12/vpu0-0a/full/2021-07-06_01-58-17.886617938_219_2170.122577874
# launched image ingestion pipeline f4bec690-e6e9-46b4-bd99-a0be2273c604 on key dcm12/vpu0-0a/full/2021-07-02_22-35-20.129810593_210_367.373330337
# launched image ingestion pipeline d2d0e875-dad9-46b0-adef-c032f8352f1d on key dcm12/vpu0-0a/full/2021-07-06_01-47-51.459748638_219_1543.695708286
# launched image ingestion pipeline d81ceac5-4d53-41f5-a165-a683f7e32074 on key dcm12/vpu0-0a/full/2021-07-06_02-00-24.417132157_219_2296.653092061
# launched image ingestion pipeline 34ebd0e1-69f2-4bed-bbdb-2039d36dc78f on key dcm12/vpu0-0a/full/2021-07-03_21-02-23.558787295_215_1111.978825087
# launched image ingestion pipeline 970fef0e-b995-4e01-b8d9-58a54c8e24ad on key dcm12/vpu0-0a/full/2021-06-26_22-03-40.382436129_188_1256.777743329
# launched image ingestion pipeline dba08f46-7cdc-4789-b857-da8def878f4b on key dcm12/vpu0-0a/full/2021-06-26_23-12-35.375353854_189_1526.578846782
# launched image ingestion pipeline f07f0b75-f1ff-466d-aadf-f47c6d375c41 on key dcm12/vpu0-0a/full/2021-07-03_23-48-10.635908638_216_1124.904602142
# launched image ingestion pipeline de4578da-b64f-416f-a4e6-33fbca8302f8 on key dcm12/vpu0-0a/full/2021-07-06_01-56-16.382373357_219_2048.618333421
# launched image ingestion pipeline 6f11461c-3f20-4db0-916c-adb703651783 on key dcm12/vpu0-0a/full/2021-07-06_01-45-47.879065700_219_1420.115025476
# launched image ingestion pipeline 3e0117e2-3e20-437c-869e-8497bf69400b on key dcm12/vpu0-0a/full/2021-07-03_19-41-06.316792839_214_618.434514551
# launched image ingestion pipeline 9dd9b059-0392-4fa1-9aad-fd82ed90bf17 on key dcm12/vpu0-0a/full/2021-07-01_23-28-53.538225867_204_1346.973619115
# launched image ingestion pipeline 5ea392f9-8525-48c6-b319-c7735426f4de on key dcm12/vpu0-0a/full/2021-07-06_18-32-43.677948324_223_1056.926173289
# launched image ingestion pipeline 697834ba-abc6-45c2-b84c-dc4fbbcafb97 on key dcm12/vpu0-0a/full/2021-07-03_21-00-04.965819830_215_973.385857590
# launched image ingestion pipeline ddb847eb-7454-4497-88c2-f32d46d8d0a1 on key dcm12/vpu0-0a/full/2021-07-06_01-27-09.260992008_219_301.496952104
# launched image ingestion pipeline 63e4dafe-cc81-4b73-943d-fa085fa28b5c on key dcm12/vpu0-0a/full/2021-06-26_20-02-37.312093368_187_1289.498306680
# launched image ingestion pipeline 6557977f-23d0-4555-9ab5-15ebc7b68b59 on key dcm12/vpu0-0a/full/2021-06-26_19-56-44.871504538_187_937.057717882
# launched image ingestion pipeline f3b50083-af3d-4c34-86c0-60734a724513 on key dcm12/vpu0-0a/full/2021-06-29_14-35-17.370989067_200_560.559483723
# launched image ingestion pipeline b6cafc4c-4ccf-4973-a0ff-a5c2b407363a on key dcm12/vpu0-0a/full/2021-06-26_23-08-46.396751011_189_1297.600243811
# launched image ingestion pipeline 4f9e2a76-8f9e-472c-83ca-23e38d3b38ee on key dcm12/vpu0-0a/full/2021-06-29_01-32-03.616235502_197_1987.011760878
# launched image ingestion pipeline 7dfe11f7-a74e-4d83-9955-d38b351e7a2b on key dcm12/vpu0-0a/full/2021-06-26_21-52-13.276834423_188_569.672141559
# launched image ingestion pipeline 89565f5f-6746-446b-a5fa-5dd43322d440 on key dcm12/vpu0-0a/full/2021-07-02_01-38-16.334527157_205_1106.500740757
# launched image ingestion pipeline fbf7dee0-81b6-4299-aa77-61952ba0ac78 on key dcm12/vpu0-0a/full/2021-06-29_01-37-04.808968052_197_2288.204493396
# launched image ingestion pipeline 60f69c57-ed52-409a-969f-87a213250e12 on key dcm12/vpu0-0a/full/2021-07-06_01-41-45.856232696_219_1178.092192600
# launched image ingestion pipeline 3ad49e46-a998-4ff5-b5d6-2347d80999b0 on key dcm12/vpu0-0a/full/2021-07-01_23-26-26.953589858_204_1200.388982818
# launched image ingestion pipeline 3c5fa4ba-db8e-48d1-8d38-e2011bce16a0 on key dcm12/vpu0-0a/full/2021-06-28_21-59-17.850097549_194_443.294708845
# launched image ingestion pipeline dd390e08-f80a-4669-8727-d2729bf20842 on key dcm12/vpu0-0a/full/2021-07-02_22-39-44.248037037_210_631.491556972
# launched image ingestion pipeline 98a417da-ae0e-4f0f-801c-cb5a8c31ded6 on key dcm12/vpu0-0a/full/2021-07-01_23-21-41.748469852_204_915.183863132
# launched image ingestion pipeline 5aa6e5d5-366f-454e-b295-8ce8738fbb96 on key dcm12/vpu0-0a/full/2021-06-29_19-39-10.787464123_201_983.175802651
# launched image ingestion pipeline fd24a4e2-ab79-41f2-8e58-5c75f69ebdcc on key dcm12/vpu0-0a/full/2021-07-03_19-51-28.867826470_214_1240.985548022

# %%
# This will take some time depending on the number of logfiles on the SSD
# Follow the Kubeflow runs at: https://kubeflow.brtws.com/_/pipeline/#/experiments/details/638eda8c-17cd-42be-bbb8-ab7a45647283
# You can also follow ISP processing progress at: https://grafana.brtws.com/d/AWSSQS000/aws-sqs?from=now-24h&orgId=1&to=now&var-datasource=CloudWatch&var-queue=isp_medium_priority_prod&var-region=default
for i in SSD_dirs:
    submit_image_ingestion_workflow('brt-dcm-data', i)
    time.sleep(30)
# Out:
# launched image ingestion pipeline 65ae65b7-3877-446b-9b3c-cd0541a7157e on key dcm14/0/full/2021-04-27_20-05-55.439067087_83_4210.580051503
# launched image ingestion pipeline fa0a3422-ea0e-49f9-a149-abcf5c60a3e5 on key dcm14/0/full/2021-05-05_19-46-51.726701077_104_3476.726666805
# launched image ingestion pipeline 7bf913a9-6603-40ae-9f62-be9f6a961dae on key dcm14/0/full/2021-05-05_19-08-17.343964765_104_1162.343930237
# launched image ingestion pipeline 1b6aaaad-9677-4878-93ca-577073976ded on key dcm14/0/full/2021-04-28_16-32-27.657436520_92_255.658392136
# launched image ingestion pipeline 08150ad4-4e9e-4bd4-a685-424b87b8b8b3 on key dcm14/0/full/2021-05-06_01-05-08.497570586_112_2075.684745274
# launched image ingestion pipeline 73c69a48-9592-4a68-9fb1-5515d2db4f36 on key dcm14/0/full/2021-04-30_17-49-26.123169205_98_3094.338461013
# launched image ingestion pipeline f59fc750-933f-4f6a-8932-62e3b5d0a68a on key dcm14/0/full/2021-04-30_19-10-37.565067440_100_1139.721681424
# launched image ingestion pipeline 899da349-cebd-417f-a178-b04c9fcd598a on key dcm14/0/full/2021-04-27_21-02-53.491087059_84_962.702580979
# launched image ingestion pipeline 52bfb9c1-71d6-4519-b9ca-5f820898e843 on key dcm14/0/full/2021-05-05_21-19-30.771381804_109_1198.912025900
# launched image ingestion pipeline 224c76ea-ed8f-4495-ba78-0b3873ee4332 on key dcm14/0/full/2021-05-06_00-44-03.057684649_112_810.244859049
# launched image ingestion pipeline 83e014f1-b2dd-42ce-aa6b-b0e195fc6467 on key dcm14/0/full/2021-04-28_00-16-43.641521001_87_1164.855294627
# launched image ingestion pipeline e2275574-dc8b-4f07-bdc1-8084f1e2155f on key dcm14/0/full/2021-05-05_19-35-02.224995810_104_2767.224961346
# launched image ingestion pipeline e14aa975-c7a7-4490-94c5-9f733904542d on key dcm14/0/full/2021-05-06_15-58-37.246549436_117_2716.386875356
# launched image ingestion pipeline a1f8946d-8209-4a83-adfd-4264351fdca4 on key dcm14/0/full/2021-05-06_00-34-24.149363817_112_231.336538569
# launched image ingestion pipeline bf637d2a-f957-4702-8728-d3e8d37a6933 on key dcm14/0/full/2021-04-30_17-04-10.746260836_98_378.961552484
# launched image ingestion pipeline e55b6beb-e772-442e-b831-7b5beb867313 on key dcm14/0/full/2021-04-28_15-30-14.270216368_90_6549.195256752
# launched image ingestion pipeline b52f743e-4d37-4b92-afdc-7ca756aef88c on key dcm14/0/full/2021-04-30_17-04-38.877980911_98_407.093272559
# launched image ingestion pipeline 274a4507-55fc-43e4-b103-d7e2bb92022b on key dcm14/0/full/2021-05-06_00-45-50.597731253_112_917.784905653
# launched image ingestion pipeline a21ee979-e89d-4733-97db-ef43e2ac53fe on key dcm14/0/full/2021-05-06_16-03-43.820757113_117_3022.961083129
# launched image ingestion pipeline a3f901c2-f310-4783-8485-ce31fc3df59d on key dcm14/0/full/2021-04-28_15-34-59.660047836_90_6834.585088316
# launched image ingestion pipeline 46e40353-81a2-42f7-9dba-d03bad132b6f on key dcm14/0/full/2021-05-06_15-52-13.267158955_117_2332.407485067
# launched image ingestion pipeline 0385ae65-62da-4c86-8ec2-e88cc7979d40 on key dcm14/0/full/2021-04-28_16-46-18.951178161_92_1086.952133777
# launched image ingestion pipeline 4e2e2648-510a-4152-8e2f-8d5c75388492 on key dcm14/0/full/2021-04-30_17-47-23.489452006_98_2971.704743654
# launched image ingestion pipeline 5c188625-16ab-48b5-ac2b-8f5282dac998 on key dcm14/0/full/2021-05-06_16-01-51.234006533_117_2910.374332645
# launched image ingestion pipeline 0f90cae7-90bf-4eae-9acb-1ebeb821be08 on key dcm14/0/full/2021-04-27_19-48-56.390704223_83_3191.531688607
# launched image ingestion pipeline 00c5b1c0-f417-4338-a13e-18d919c253a6 on key dcm14/0/full/2021-05-06_15-26-16.496359514_117_775.636685562
# launched image ingestion pipeline e4b6fea7-0b57-4f6c-9ca7-1941f2fc0510 on key dcm14/0/full/2021-05-05_19-13-00.770645737_104_1445.770611241
# launched image ingestion pipeline 72f018db-0d85-472a-a2e6-61c36b42abda on key dcm14/0/full/2021-04-28_16-34-13.190409707_92_361.191365418
# launched image ingestion pipeline a9a3d0a9-9324-4cfd-833a-50db95e854f1 on key dcm14/0/full/2021-04-28_16-44-23.331479496_92_971.332435144
# launched image ingestion pipeline fbdce371-b070-4af0-8381-07d7a8a318bf on key dcm14/0/full/2021-05-06_15-21-58.217743967_117_517.358070079
# launched image ingestion pipeline a58f848f-f014-402f-93dd-f48a0743d470 on key dcm14/0/full/2021-04-28_15-38-12.638090571_90_7027.563131019
# launched image ingestion pipeline 3f9eae51-e158-435e-9195-3350d489f5c8 on key dcm14/0/full/2021-04-28_16-22-20.599698743_91_355.401340183
# launched image ingestion pipeline 38f72c77-6788-473b-96bf-c199814c0efe on key dcm14/0/full/2021-05-05_19-11-11.231434289_104_1336.231400017
# launched image ingestion pipeline e3f0439d-5e8e-4313-8b64-1f65100f87d2 on key dcm14/0/full/2021-05-06_00-38-16.317051301_112_463.504225957
# launched image ingestion pipeline 9c7b9ba2-5c70-48c9-a9f9-e87928934589 on key dcm14/0/full/2021-04-30_18-03-44.336117123_98_3952.551408803
# launched image ingestion pipeline d4463aa9-3bcf-451e-80a7-3d0e15be28ce on key dcm14/0/full/2021-05-06_12-38-13.107369213_115_294.263434909
# launched image ingestion pipeline 65730bc8-2d5f-4f7a-941b-9d4fdc6ebe5d on key dcm14/0/full/2021-05-06_12-48-41.134545163_115_922.290611051
# launched image ingestion pipeline 518a9588-a993-45e8-99dd-430d23f1d167 on key dcm14/0/full/2021-04-27_21-00-44.847722093_84_834.059216141
# launched image ingestion pipeline 5551bcaa-54c4-41f2-ae9c-451d2cd5a686 on key dcm14/0/full/2021-04-28_00-22-17.398196661_87_1498.611970639
# launched image ingestion pipeline 9fbc045d-1585-4426-940e-e42f0623e70b on key dcm14/0/full/2021-05-05_19-31-18.052875675_104_2543.052841307
# launched image ingestion pipeline 30a67549-3f61-43cb-96df-10f0400933e6 on key dcm14/0/full/2021-04-30_17-00-32.695391598_98_160.910683406
# launched image ingestion pipeline 1df270c9-e55f-4092-8a0a-d3dbbe3cdc1d on key dcm14/0/full/2021-04-28_00-38-03.289607073_87_2444.503381147
# launched image ingestion pipeline c90e1dc6-1820-4441-94dd-36a50c8f8044 on key dcm14/0/full/2021-04-30_17-43-29.340594665_98_2737.555886345
# launched image ingestion pipeline b2d0d9ab-8920-4cf0-9ea5-b6ffc714a988 on key dcm14/0/full/2021-04-28_00-26-15.646138229_87_1736.859911983
# launched image ingestion pipeline df2e8779-8420-4d18-9d6c-1efabf217e01 on key dcm14/0/full/2021-04-27_19-11-52.669841578_83_967.810825930
# launched image ingestion pipeline 65eae48a-3c62-4e76-8ec1-7d850851d477 on key dcm14/0/full/2021-05-06_15-24-04.833482014_117_643.973808190
# launched image ingestion pipeline f4fe37a4-67a9-4c37-b1be-2c4cc3f74e57 on key dcm14/0/full/2021-04-28_16-37-05.080656408_92_533.081612024
# launched image ingestion pipeline 3a02c6a3-2b9e-4bba-a46c-5ff2c06c9221 on key dcm14/0/full/2021-04-30_17-52-26.000005576_98_3274.215297192
# launched image ingestion pipeline 4034ed2e-f7fa-40fe-8eda-23ad77ba3a8f on key dcm14/0/full/2021-05-06_15-30-26.730431971_117_1025.870757827
# launched image ingestion pipeline 5cfc6981-94c2-4b6f-a6e2-ab0678bab9ac on key dcm14/0/full/2021-05-05_19-15-03.346899808_104_1568.346865344
# launched image ingestion pipeline ed64fe96-aa03-48c9-85e7-643f377f0e44 on key dcm14/0/full/2021-04-30_18-55-42.885642035_100_245.042255827
# launched image ingestion pipeline 3ec38dc0-7292-446f-bbd4-a6e5f6ae08f8 on key dcm14/0/full/2021-04-28_15-37-52.548737081_90_7007.473777689
# launched image ingestion pipeline 98e2a8b6-dd35-4ce1-9f46-0850aba143d7 on key dcm14/0/full/2021-05-05_19-05-17.491189753_104_982.491155289
# launched image ingestion pipeline b1be5c3f-4227-47e5-b01e-9815e43e946e on key dcm14/0/full/2021-05-05_19-37-43.994846537_104_2928.994812232
# launched image ingestion pipeline e2f06e91-311b-4d95-96c7-ce2facc38a98 on key dcm14/0/full/2021-04-27_12-49-53.475538137_81_1860.475814009
# launched image ingestion pipeline 5f30c126-3905-4847-9a0c-ac4c7ae9b0db on key dcm14/0/full/2021-04-30_17-15-13.165282216_98_1041.380573768
# launched image ingestion pipeline 0ae808e4-0a79-4cdd-9171-268d5b7a0609 on key dcm14/0/full/2021-04-30_17-10-52.809228848_98_781.024520527
# launched image ingestion pipeline c6c17538-67ae-4ddf-9f63-7e493a531b1e on key dcm14/0/full/2021-04-27_19-58-10.139585489_83_3745.280570001
# launched image ingestion pipeline 727e5ceb-3a1d-4af2-ae3c-db1cf4181662 on key dcm14/0/full/2021-04-27_21-09-53.649744757_84_1382.861238645
# launched image ingestion pipeline 89ffea94-366a-4ca3-bdce-073745f10bd9 on key dcm14/0/full/2021-05-06_15-54-59.130331910_117_2498.270657958
# launched image ingestion pipeline bf116899-23d8-46ed-bf06-2b75785db2d6 on key dcm14/0/full/2021-05-06_12-45-19.170270987_115_720.326336875
# launched image ingestion pipeline 2c27ebf5-9872-4302-986e-6252f6cbd3a3 on key dcm14/0/full/2021-04-30_19-02-57.159412969_100_679.316026793
# launched image ingestion pipeline f911846e-d798-4a47-9315-971f654d601a on key dcm14/0/full/2021-04-30_19-13-53.637201574_100_1335.793815494
# launched image ingestion pipeline e6c4bf7e-ca97-493e-924d-a102989c4e1d on key dcm14/0/full/2021-04-30_17-20-25.681017030_98_1353.896308550
# launched image ingestion pipeline f7e8c89b-5056-4bf7-a5ac-80b6fc1a3b8a on key dcm14/0/full/2021-04-27_19-10-10.173663405_83_865.314647821
# launched image ingestion pipeline 085c61f1-7009-4d1f-bfd2-98c157f90324 on key dcm14/0/full/2021-04-30_19-16-10.393721072_100_1472.550334864
# launched image ingestion pipeline b9dc7ae8-2eae-41d1-a153-60fea3abc7bf on key dcm14/0/full/2021-04-27_13-08-01.858153829_81_2948.858429701
# launched image ingestion pipeline 73088860-bd58-4f5f-99e1-b595568e6a54 on key dcm14/0/full/2021-04-28_00-08-13.045422137_87_654.259196147
# launched image ingestion pipeline bbf5f9bf-15f5-453f-b426-daa3b58ec16e on key dcm14/0/full/2021-04-27_13-04-22.780054975_81_2729.780330815
# launched image ingestion pipeline b6c82063-64d7-4dee-9bc7-639686f70135 on key dcm14/0/full/2021-04-28_16-41-38.483762090_92_806.484717642
# launched image ingestion pipeline d2ec07bb-9b49-4667-bb70-102f02f7830e on key dcm14/0/full/2021-04-27_12-47-42.797277515_81_1729.797553291
# launched image ingestion pipeline 671a3679-40a5-43ce-bfaa-5049e2cdd46d on key dcm14/0/full/2021-04-28_00-36-06.677050357_87_2327.890824367
# launched image ingestion pipeline f02aa200-c164-4ded-a08c-f1ed40804a40 on key dcm14/0/full/2021-05-05_21-05-09.631867023_109_337.772510959
# launched image ingestion pipeline 1bebfb4f-9721-4158-917d-dca739d70340 on key dcm14/0/full/2021-05-05_19-33-07.602930512_104_2652.602895952
# launched image ingestion pipeline 8f29cc2a-28c2-4a7d-b91b-f1dad2ce9f23 on key dcm14/0/full/2021-04-27_19-03-45.330721085_83_480.471705436
# launched image ingestion pipeline 3b1d4373-b053-4f9a-9493-0189a7ef5a78 on key dcm14/0/full/2021-04-27_20-00-06.717668035_83_3861.858652451
# launched image ingestion pipeline f6d2796b-fc62-4ea8-bca7-a8e174eaa2d4 on key dcm14/0/full/2021-05-05_19-16-44.856545829_104_1669.856511589
# launched image ingestion pipeline 81cea109-8690-4b9b-ad05-7e69a23a6e82 on key dcm14/0/full/2021-04-27_21-12-11.378484484_84_1520.589978372
# launched image ingestion pipeline 42ec704e-9dbc-481f-9203-1437e91b9380 on key dcm14/0/full/2021-05-05_19-05-04.425847417_104_969.425813017
# launched image ingestion pipeline 52bf9dc9-9a8a-45e4-b16c-6e164d39fc23 on key dcm14/0/full/2021-04-30_19-08-27.878446502_100_1010.035060326
# launched image ingestion pipeline 47ee81c1-7ccf-4712-97e0-ab0096fea6db on key dcm14/0/full/2021-05-06_00-41-57.418790870_112_684.605965461
# launched image ingestion pipeline 522c6b65-f5a2-4c38-b811-6410197ed18a on key dcm14/0/full/2021-05-06_01-01-54.523285738_112_1881.710460362
# launched image ingestion pipeline bab65e1e-da19-4a7f-91eb-6c2c2d1d4bf4 on key dcm14/0/full/2021-04-27_18-59-28.075941317_83_223.216925797
# launched image ingestion pipeline 43123f58-5ca5-48e0-93a9-528d0d3c7343 on key dcm14/0/full/2021-04-27_19-06-07.985485843_83_623.126469939
# launched image ingestion pipeline e96037d9-69aa-45eb-8d5e-f1ba2595673c on key dcm14/0/full/2021-04-28_00-20-27.813749903_87_1389.027523625
# launched image ingestion pipeline 3f103cb9-40c8-4744-aab1-efebbd06c08f on key dcm14/0/full/2021-04-30_17-59-45.179701038_98_3713.394992622
# launched image ingestion pipeline e5cdd873-2ffc-4066-b9fb-d5fe11816356 on key dcm14/0/full/2021-04-30_18-55-26.804146137_100_228.960759961
# launched image ingestion pipeline c03f26dc-7d91-4768-bddc-326bbcf2b606 on key dcm14/0/full/2021-04-27_19-01-50.769441140_83_365.910425492
# launched image ingestion pipeline 97814e6c-ed0f-4163-8d1a-8d68c0b3063e on key dcm14/0/full/2021-04-28_00-34-14.084909561_87_2215.298683635
# launched image ingestion pipeline d7213743-d0e6-432e-a3ab-0eedc20ed902 on key dcm14/0/full/2021-05-05_19-48-52.310854267_104_3597.310819739
# launched image ingestion pipeline f00e1c75-49f2-428e-bac4-02c565bda3dc on key dcm14/0/full/2021-05-05_19-41-45.217267167_104_3170.217232703
# launched image ingestion pipeline fd2135e1-910f-4a9f-bc98-14c2eeb64e97 on key dcm14/0/full/2021-04-27_21-05-50.388798023_84_1139.600291815
# launched image ingestion pipeline 4083dbc3-5932-4a45-b58b-8c132042c922 on key dcm14/0/full/2021-05-06_12-37-31.923192986_115_253.079258746
# launched image ingestion pipeline 3d40df80-7820-4c10-83a4-a399ef51af1a on key dcm14/0/full/2021-04-28_15-32-19.883212126_90_6674.808252734
# launched image ingestion pipeline fba33721-4f03-4a79-9317-024e34497349 on key dcm14/0/full/2021-04-28_16-20-21.005964946_91_235.807606226
# launched image ingestion pipeline 75ac153e-8713-4522-890b-df6872ccbbfa on key dcm14/0/full/2021-05-05_21-13-46.125294699_109_854.265938923
# launched image ingestion pipeline 0248f7e3-f2a6-49b6-8d7a-765fbde097db on key dcm14/0/full/2021-04-30_17-54-27.618071073_98_3395.833362721
# launched image ingestion pipeline c71e096f-8813-4d0f-a955-92fef57e8430 on key dcm14/0/full/2021-04-27_19-51-32.195673890_83_3347.336658274
# launched image ingestion pipeline 6cbfc912-3852-4387-8c29-702ace7ea9ab on key dcm14/0/full/2021-04-28_00-40-21.027211705_87_2582.240985491
# launched image ingestion pipeline e9319c2f-b21f-412d-ba2e-1c332ba20dbd on key dcm14/0/full/2021-05-06_16-07-46.115821607_117_3265.256147591
# launched image ingestion pipeline e938e2b4-f31a-4d3c-9f3a-4872aa196db6 on key dcm14/0/full/2021-05-06_15-19-37.494620567_117_376.634946455
# launched image ingestion pipeline e65efb9b-9134-4d64-9372-de496bfdc58b on key dcm14/0/full/2021-04-30_17-06-38.495121883_98_526.710413371
# launched image ingestion pipeline d657903d-1cc8-4c88-b405-dca570d5b929 on key dcm14/0/full/2021-05-04_15-53-41.022940558_103_2216.494554576
# launched image ingestion pipeline fc923d7c-1914-449c-bdae-3c46a69cfafe on key dcm14/0/full/2021-05-06_16-00-02.669417622_117_2801.809743701
# launched image ingestion pipeline 404d5a72-4c04-4eea-bd93-12dea3c6281b on key dcm14/0/full/2021-04-28_00-26-22.679417852_87_1743.893191926
# launched image ingestion pipeline 873b2055-3dae-44a0-b31e-80fa70159243 on key dcm14/0/full/2021-05-06_15-56-58.738468299_117_2617.878794347
# launched image ingestion pipeline 2e4123a8-8cf7-4aa9-9514-a3e48b756305 on key dcm14/0/full/2021-05-06_16-05-31.423859937_117_3130.564186177
# launched image ingestion pipeline 1eb2ef38-23de-448d-b0e2-65c277ee07cc on key dcm14/0/full/2021-05-06_00-36-25.729390290_112_352.916564978
# launched image ingestion pipeline c4b3c890-7952-40be-a412-4dac1c7dc2f4 on key dcm14/0/full/2021-04-30_17-12-44.375887235_98_892.591178915
# launched image ingestion pipeline cf3ae64c-8652-4d44-88bb-1a8b9405c718 on key dcm14/0/full/2021-05-05_19-39-42.578186588_104_3047.578151900
# launched image ingestion pipeline bf199a87-2c12-4786-9c5b-d21d44e1bb5c on key dcm14/0/full/2021-05-05_21-02-58.969617712_109_207.110261744
# launched image ingestion pipeline 10383879-269e-4b12-9c86-0af92c5a1847 on key dcm14/0/full/2021-04-30_17-40-53.562508390_98_2581.777800230
# launched image ingestion pipeline ba3e6042-9239-400f-beeb-5ceadd6cf7fb on key dcm14/0/full/2021-05-05_19-02-43.772918387_104_828.772884083
# launched image ingestion pipeline de400bae-0502-4413-8fe5-9fee7c570aa3 on key dcm14/0/full/2021-04-27_19-18-38.673226603_83_1373.814210954
# launched image ingestion pipeline 77df17d2-c7c5-4518-a8bd-66e90402f92f on key dcm14/0/full/2021-05-06_00-47-27.103534444_112_1014.290708972
# launched image ingestion pipeline 74e1a3f2-b02c-457e-a21d-845b18abe26e on key dcm14/0/full/2021-04-27_19-49-44.675956880_83_3239.816917999
# launched image ingestion pipeline 0905b279-b721-4a35-be49-6a961f48dfb5 on key dcm14/0/full/2021-05-06_00-39-56.809908902_112_563.997083558
# launched image ingestion pipeline fbd0a417-5ca7-4790-9125-3130383a909d on key dcm14/0/full/2021-05-04_15-44-43.501481118_103_1678.973095104
# launched image ingestion pipeline a907c068-3c8e-4d10-9b6f-6f37b1392dbf on key dcm14/0/full/2021-04-28_16-22-02.507671800_91_337.309312600
# launched image ingestion pipeline efa9223d-d869-4400-a499-9ea7cc5d7dd5 on key dcm14/0/full/2021-05-06_12-41-52.187761150_115_513.343826878
# launched image ingestion pipeline 979c6d4a-cf7c-4fa4-a6b9-c84858572047 on key dcm14/0/full/2021-05-06_01-03-33.015488191_112_1980.202663039
# launched image ingestion pipeline 1017d785-039e-46e2-be9f-a84dbb34fb63 on key dcm14/0/full/2021-04-30_17-01-11.867575402_98_200.082867018
# launched image ingestion pipeline aa1781af-a9bc-4b0b-a612-834479e0585e on key dcm14/0/full/2021-05-05_21-09-46.961872770_109_615.102516770
# launched image ingestion pipeline 26bb0891-0cf1-4392-945a-f85c10e6a2c0 on key dcm14/0/full/2021-05-06_15-32-30.377914471_117_1149.518240519
# launched image ingestion pipeline 15855cf1-5aee-432a-80b5-725c39a1f3c2 on key dcm14/0/full/2021-04-27_20-12-01.140739400_83_4576.281723688
# launched image ingestion pipeline 58f329a8-bd0f-4ac2-8bb9-fd3cea10062e on key dcm14/0/full/2021-04-27_20-58-27.165421925_84_696.376915941
# launched image ingestion pipeline d43e4c16-7144-4db8-b3cc-697ad1ad28be on key dcm14/0/full/2021-05-06_00-58-34.512882443_112_1681.700057131
# launched image ingestion pipeline 6948a9e8-9430-4347-9883-46de0952c37d on key dcm14/0/full/2021-05-05_21-21-20.300807205_109_1308.441451237
# launched image ingestion pipeline bf8af39b-da43-410b-bcf2-dc2fd00594c4 on key dcm14/0/full/2021-04-27_13-02-27.201676387_81_2614.201952259
# launched image ingestion pipeline 66a6b24f-dc04-4fc8-be4a-2c07c9a029dd on key dcm14/0/full/2021-05-05_21-12-03.603093108_109_751.743723251
# launched image ingestion pipeline 2e86b13f-8da7-46a3-a88c-9b89951f1628 on key dcm14/0/full/2021-05-06_12-43-33.667545232_115_614.823610927
# launched image ingestion pipeline 24e8b3da-1469-44cc-ae74-eafc3f25d990 on key dcm14/0/full/2021-05-06_00-49-15.691098894_112_1122.878273550
# launched image ingestion pipeline ed31025d-ede8-4aac-a39f-e51e22a42c89 on key dcm14/0/full/2021-05-06_01-08-30.519927109_112_2277.707101701
# launched image ingestion pipeline edab7531-5424-4e77-8236-0e31533bff50 on key dcm14/0/full/2021-04-30_17-18-10.040692358_98_1218.255984038
# launched image ingestion pipeline ec6a16eb-01bc-440d-a5d3-78ffbc61c389 on key dcm14/0/full/2021-05-06_15-17-02.731988552_117_221.872314760
# launched image ingestion pipeline 88b8996f-95c5-47d9-b782-99c66ba8b490 on key dcm14/0/full/2021-05-06_15-28-29.160307728_117_908.300633744
# launched image ingestion pipeline 83fcfc8a-1512-4f8e-829a-4ae7b4773579 on key dcm14/0/full/2021-05-06_12-46-50.611975157_115_811.768040597
# launched image ingestion pipeline d9988071-f4c3-4f14-a411-8f057354e0db on key dcm14/0/full/2021-04-27_19-54-38.140170446_83_3533.281154670
# launched image ingestion pipeline 95a5ded6-5d6a-4fa2-8435-f729b2ca7808 on key dcm14/0/full/2021-05-05_21-16-20.856705702_109_1008.997349862
# launched image ingestion pipeline 1a73b326-d56d-4e61-9cec-95ed4eee1774 on key dcm14/0/full/2021-04-30_17-08-38.133907464_98_646.349199144
# launched image ingestion pipeline 44e0efe6-1729-4ef8-8449-402cf12b95c4 on key dcm14/0/full/2021-04-27_21-14-13.998428056_84_1643.209921784
# launched image ingestion pipeline fca788e0-a3be-45bc-97cf-f7940315a1d7 on key dcm14/0/full/2021-05-04_16-16-38.484950685_103_3593.956564575
# launched image ingestion pipeline c89ced66-f7f5-4a05-a15f-86185460974f on key dcm14/0/full/2021-05-06_00-56-19.818405131_112_1547.005579883
# launched image ingestion pipeline b03b8062-74fc-4133-9a1e-5164e4b1e9b5 on key dcm14/0/full/2021-04-28_00-12-33.331762915_87_914.545536797
# launched image ingestion pipeline 504d591b-80c0-4e19-943b-6b358cad8635 on key dcm14/0/full/2021-04-27_20-02-06.294821490_83_3981.435805778
# launched image ingestion pipeline 017d17d7-0fbc-43fe-9f09-2d2dfe0a5e44 on key dcm14/0/full/2021-05-05_19-18-34.395960936_104_1779.395926600
# launched image ingestion pipeline 07a1cbca-445a-4e5a-9460-8bcad562e678 on key dcm14/0/full/2021-04-30_17-56-06.122855853_98_3494.338147437
# launched image ingestion pipeline 4d61862d-b652-4f68-b93c-e10c49edcc3b on key dcm14/0/full/2021-05-06_01-10-11.084238454_112_2378.271413110
# launched image ingestion pipeline 1f2f5370-ddf2-4c29-ba4f-478c0ef73261 on key dcm14/0/full/2021-05-06_12-36-01.511897422_115_162.667963182
# launched image ingestion pipeline 0510ef5b-d47f-432f-a74e-6e6c67022548 on key dcm14/0/full/2021-04-28_00-14-48.023550657_87_1049.237324507
# launched image ingestion pipeline 519d8307-c522-4e79-8770-f03e4480246d on key dcm14/0/full/2021-04-27_13-00-20.584036495_81_2487.584312271
# launched image ingestion pipeline cf07ff84-b626-4292-a7fa-791cb052b106 on key dcm14/0/full/2021-04-27_19-08-24.644660295_83_759.785644615
# launched image ingestion pipeline b2e25b0c-4a98-4b8d-a6df-1f145bc03947 on key dcm14/0/full/2021-04-27_12-51-41.003050654_81_1968.003326526
# launched image ingestion pipeline 52f82dd0-4c10-444a-b865-fc90b7400872 on key dcm14/0/full/2021-04-27_21-17-18.982249461_84_1828.193743605
# launched image ingestion pipeline 0178a202-5cc7-476a-b55d-45314714f0ca on key dcm14/0/full/2021-04-27_19-46-56.792779376_83_3071.933763760
# launched image ingestion pipeline 84b717ea-af8f-48ee-b162-e9b2da7027c3 on key dcm14/0/full/2021-04-28_00-18-45.279208950_87_1286.492982960
# launched image ingestion pipeline fe6362b8-522e-4a0a-b553-cb96e8e4f60f on key dcm14/0/full/2021-05-06_12-39-44.581760621_115_385.737826253
# launched image ingestion pipeline af438f50-4289-49fa-9aa9-297b70b258b3 on key dcm14/0/full/2021-04-30_19-00-29.378001614_100_531.534615374
# launched image ingestion pipeline ceecec48-2afa-4493-9cac-a02a896d2ea4 on key dcm14/0/full/2021-04-28_16-39-54.908816035_92_702.909771747
# launched image ingestion pipeline f0ce2c1c-9c4d-4fc9-a42b-fb7f2c2da177 on key dcm14/0/full/2021-05-05_21-07-47.377641961_109_495.518285801
# launched image ingestion pipeline ffa6d30f-324b-4f17-9780-e2a22794364c on key dcm14/0/full/2021-04-27_21-07-59.038319091_84_1268.249813011
# launched image ingestion pipeline 27876f0a-79f0-40ea-9dae-54a4a38bedbf on key dcm14/0/full/2021-04-30_19-05-39.970929807_100_842.127543759
# launched image ingestion pipeline efdd0ce6-f002-4fd1-949d-bba1abe1e79b on key dcm14/0/full/2021-05-05_19-43-53.822963648_104_3298.822929120
# launched image ingestion pipeline d5b18536-e88b-4717-a746-00e3aaf00a58 on key dcm14/0/full/2021-04-27_13-10-19.549236655_81_3086.549512335
# launched image ingestion pipeline 54219a07-4108-4552-a286-d268202a3d89 on key dcm14/0/full/2021-04-28_00-10-39.769571889_87_800.983345931
# launched image ingestion pipeline b3397c77-83c7-424d-a1f1-ca46a5e2a913 on key dcm14/0/full/2021-05-06_12-50-27.665302578_115_1028.821368466
# launched image ingestion pipeline 3c2cd33a-05c0-425d-ae76-f491105bd75d on key dcm14/0/full/2021-04-30_18-58-07.655413014_100_389.812026838

# %% [markdown]
# ### After Waiting For ISP Processing of NRG Images to Complete, Verify Ingest Has Concluded Successfully
# First, query aletheia for all 2021 DCM data (or a subset if you know where to look for the specific logs)

# %%
import pandas as pd
import time
import numpy as np
from matplotlib import pyplot as plt, rcParams

import brtdevkit
from brtdevkit.core.db import DBConnector, DatetimeFilter
from brtdevkit.core.db.db_filters import *  # We need this for pre-defined filters, e.g., ProjectFilter, DatetimeFilter

def get_shasta_data(filters={}, start=None, end=None, limit=None):
    """
    Query relevant Shasta data for calculations. 
    """
    start_time = time.time()
    connector = DBConnector()
    img_filters = {'project_name': 'shasta', **filters}
    if start is not None or end is not None:
        img_filters = [img_filters, DatetimeFilter(key="collected_on", start=start, end=end)]
    df = connector.get_documents_df('image', img_filters, limit=limit)
    elapsed_time = time.time() - start_time
    return df, elapsed_time

start = datetime(2021,3, 29) # The first field was collected on 3/30/2021
end = datetime(2021, 7, 28)

dcms_2021_1 = ['DCM11', 'DCM12', 'DCM13', 'DCM14', 'DCM15', 'DCM16', 'DCM17', 'DCM18', 'DCM19']
dcms_2021_2 = ['DCM20', 'DCM21', 'DCM22', 'DCM23', 'DCM24', 'DCM25', 'DCM26', 'DCM27', 'DCM28']
machines_2021 = ['DB1', 'DB2', 'DB3', 'DB4', 'DB5', 'DB6', 'DB7', 'DB8', 'DB9', 'DBMULE2']

dcms_2020 =  ['DCM-MANATEE', 'DCM-WALRUS', 'DCM-SEAL', 'DCM-OTTER', 'DCM-PORPOISE', 'DCM-DOLPHIN']
#{'$in': dcms_2021} 

filters = {"artifacts.kind": "nrg", 'robot_name' : 'DB9'
          }

df, elapsed_time = get_shasta_data(filters=filters, start=start, end=end)
#df['grower_farm_field'] = df['grower'] + '_' + df['farm'] + '_' + df['operating_field_name']
print(f"Queried {len(df)} images in {elapsed_time:.2f} s.")
# Out:
# Queried 427997 images in 189.23 s.

# %%
# For Brazilian DCMs

dolphin , f = get_logfile_directories('brt-dcm-data', 'dolphin-sysbox1')
otter , f = get_logfile_directories('brt-dcm-data', 'otter-sysbox1')

in_s3_br = set(otter + dolphin)
len(in_s3_br)
# Out:
# 1345

# %%
# Check to see if all DCM logs in S3 are accounted for in the Aletheia database
# If Desired, Verify all DCM Logs in s3 (recommended periodically)

dcm11 , f = get_logfile_directories('brt-dcm-data', 'dcm11')
dcm12 , f = get_logfile_directories('brt-dcm-data', 'dcm12')
dcm13 , f = get_logfile_directories('brt-dcm-data', 'dcm13')
dcm14 , f = get_logfile_directories('brt-dcm-data', 'dcm14')
dcm15, f = get_logfile_directories('brt-dcm-data', 'dcm15')
dcm16 , f = get_logfile_directories('brt-dcm-data', 'dcm16')
dcm17, f = get_logfile_directories('brt-dcm-data', 'dcm17')
dcm18 , f = get_logfile_directories('brt-dcm-data', 'dcm18')
dcm19, f = get_logfile_directories('brt-dcm-data', 'dcm19')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-3fe7f9914200> in <module>
#      12 dcm19, f = get_logfile_directories('brt-dcm-data', 'dcm19')
#      13
# ---> 14 in_s3 =  set(dcm11 + dcm12 + dcm13 + dcm14  + dcm16 + dcm17 + dcm18 +dcm19 + dcm20)
#
# NameError: name 'dcm20' is not defined

# %%
dcm20 , f = get_logfile_directories('brt-dcm-data', 'dcm20')
dcm21 , f = get_logfile_directories('brt-dcm-data', 'dcm21')
dcm22 , f = get_logfile_directories('brt-dcm-data', 'dcm22')
dcm23 , f = get_logfile_directories('brt-dcm-data', 'dcm23')
dcm24, f = get_logfile_directories('brt-dcm-data', 'dcm24')
dcm25 , f = get_logfile_directories('brt-dcm-data', 'dcm25')
dcm26, f = get_logfile_directories('brt-dcm-data', 'dcm26')
dcm27 , f = get_logfile_directories('brt-dcm-data', 'dcm27')
dcm28, f = get_logfile_directories('brt-dcm-data', 'dcm28')

# %%
dcm11 , f = get_logfile_directories('brt-dcm-data', 'dcm11')
dcm12 , f = get_logfile_directories('brt-dcm-data', 'dcm12')
dcm14 , f = get_logfile_directories('brt-dcm-data', 'dcm14')

jft = set(dcm11 + dcm12 + dcm14)
len(jft)
# Out:
# 2480

# %%
db, f = get_logfile_directories('brt-dcm-data', 'db2')
missing = verify_ingest(df, set(db))
print(len(np.unique(missing)))
print(sorted(np.unique(missing))[0:10])
# Out:
# There are 52 s3 logs not accounted for in Aletheia.
# 52
# ['dcm33/0/full/2021-05-19_19-03-12.248710678_17_2305.474838075', 'dcm33/0/full/2021-05-19_22-15-14.277825634_20_408.951241649', 'dcm33/0/full/2021-05-19_22-15-19.302720335_20_413.976136446', 'dcm33/0/full/2021-05-19_22-15-27.334432646_20_422.007848597', 'dcm33/vpu0-0a/full/2021-06-01_18-51-31.526544343_28_1516.611694551', 'dcm33/vpu0-0a/full/2021-06-01_18-52-41.842929970_28_1586.928080082', 'dcm33/vpu0-0a/full/2021-06-01_18-54-03.172883551_28_1668.258033727', 'dcm33/vpu0-0a/full/2021-06-01_18-55-08.471716609_28_1733.556866817', 'dcm33/vpu0-0a/full/2021-06-01_18-56-20.808882251_28_1805.894032427', 'dcm33/vpu0-0a/full/2021-06-01_18-57-40.149592492_28_1885.234742700']

# %%
mi = [i for i in missing if i[0:13] == 'dcm16/vpu0-0a']
mi[0:5]
# Out:
# ['dcm16/vpu0-0a/full/2021-05-31_15-34-54.251941500_116_355.405043484',
#  'dcm16/vpu0-0a/full/2021-05-31_15-40-33.545393449_116_694.698495209',
#  'dcm16/vpu0-0a/full/2021-05-31_15-44-15.366226473_116_916.519328457',
#  'dcm16/vpu0-0a/full/2021-05-31_15-48-35.337014065_116_1176.490115761',
#  'dcm16/vpu0-0a/full/2021-05-31_15-51-54.102441530_116_1375.255543353']

# %%
def verify_ingest_db(df, in_s3, robot_name):
    """
    Given a dataframe of all DCM images from 2021, and a list of logfiles in S3, find the difference between the two.
    These will be the logfiles we still need to ingest. 
    """
    # Check which s3_paths are present in Aletheia (2021 data only)
    paths = list(df.s3_path.unique())
    paths = [ p for p in paths if (p[0:18] == 's3://brt-dcm-data/') ]
    paths = [p.split('s3://brt-dcm-data/')[1] for p in paths]
    in_db = [p.split('/log')[0] for p in paths]
    print(in_s3[0:5])
    # omit logs from vpu0-0a
    in_s3 = [v for v in in_s3  if (v.split(robot_name)[1][0:8] != '/vpu0-0a')]
    # omit anthing but full logs
    in_s3 = [v for v in in_s3  if len(v.split('full'))>1]
    in_s3 = set([d.split('/log')[0] for d in in_s3])
    missing = list(in_s3.difference(in_db))
    print(f'There are {len(missing)} s3 logs not accounted for in Aletheia.')
    return missing

robot = 'db9'
db, f = get_logfile_directories('brt-dcm-data', robot)
indb = verify_ingest_db(df, db, robot)

len(indb)
# Out:
# ['db9/vpu0-0a/full/2021-04-20_19-44-39.934046338_79_13567.642429221', 'db9/vpu0-0a/full/2021-04-20_19-44-39.934046338_79_13567.642429221/log_timestamps/0/aos/remote_timestamps/vpu0-10a/0/aos/aos-message_bridge-Timestamp', 'db9/vpu0-0a/full/2021-04-20_19-44-39.934046338_79_13567.642429221/log_timestamps/0/aos/remote_timestamps/vpu0-10a/lead/brt-SystemParameters', 'db9/vpu0-0a/full/2021-04-20_19-44-39.934046338_79_13567.642429221/log_timestamps/0/aos/remote_timestamps/vpu0-10a/pose/brt-vpu-pose-fbs-Origin', 'db9/vpu0-0a/full/2021-04-20_19-44-39.934046338_79_13567.642429221/log_timestamps/0/aos/remote_timestamps/vpu0-11a/0/aos/aos-message_bridge-Timestamp']
# There are 755 s3 logs not accounted for in Aletheia.
# 755

# %%
vpus = [n for n in indb if n[4] == 'v']
print(len(indb))
len(np.unique(vpus))
# Out:
# 755
# 755

# %%
vpus[0:10]
# Out:
# ['db9/vpu0-4a/full/2021-06-04_19-31-43.089322973_261_4519.567481783',
#  'db9/vpu0-3a/full/2021-06-10_19-45-28.298933093_289_9469.614497722',
#  'db9/vpu0-12a/full/2021-06-05_21-05-13.838737011_277_892.415336059',
#  'db9/vpu0-14a/full/2021-05-08_17-34-34.281011488_173_12894.541370553',
#  'db9/vpu0-12a/full/2021-06-08_17-34-34.440144858_294_588.713912895',
#  'db9/vpu0-14a/full/2021-06-16_21-00-19.237840838_344_12466.923374850',
#  'db9/vpu0-13a/full/2021-05-11_20-01-39.059219095_181_6080.488913710',
#  'db9/vpu0-4a/full/2021-05-08_16-57-22.701320519_168_10663.101777460',
#  'db9/vpu0-11a/full/2021-06-15_15-27-27.702873433_334_2705.108433287',
#  'db9/vpu0-2a/full/2021-06-05_21-27-14.976913604_268_2213.786690860']

# %%
df = None

# %%
in_s3 =  set(dcm20 + dcm21 + dcm22 + dcm23  + dcm24 + dcm25 + dcm26 +dcm27 + dcm28 )
len(in_s3)
# Out:
# 907

# %%
for i in vpus:
    submit_image_ingestion_workflow('brt-dcm-data', i)
    time.sleep(30)
# Out:
# launched image ingestion pipeline cee6ccfe-9bc6-4488-8215-b810e866c5df on key dcm25/vpu0-0a/full/2021-05-24_18-20-55.241924798_56_2152.541077182
# launched image ingestion pipeline aa20edac-1213-4de1-8ef0-344a3445cc2d on key dcm25/vpu0-0a/full/2021-05-20_22-25-51.571510008_49_664.776981464
# launched image ingestion pipeline cb6bbfcc-75e7-4393-89c3-d3f1065d9e3e on key dcm25/vpu0-0a/full/2021-05-27_14-54-29.040817782_76_384.445881078
# launched image ingestion pipeline c9ccc417-c052-4f02-9c4e-c5f67864b3bc on key dcm25/vpu0-0a/full/2021-05-27_15-13-58.655300800_76_1554.060364160
# launched image ingestion pipeline 31d79524-8963-401a-bee6-f4b9d85be1af on key dcm25/vpu0-0a/full/2021-05-21_15-38-17.129990254_53_842.342395054
# launched image ingestion pipeline c83f044a-efec-45ac-a954-f046161ddbd9 on key dcm25/vpu0-0a/full/2021-05-24_21-16-24.963515086_58_855.438916430
# launched image ingestion pipeline a44a6784-6304-42f7-a90b-bf4e9d8832f5 on key dcm25/vpu0-0a/full/2021-05-25_20-11-44.319817129_66_1145.684120969
# launched image ingestion pipeline 405136b1-523d-475d-bfda-216b0ddbcccb on key dcm25/vpu0-0a/full/2021-05-30_15-40-39.021961935_86_1319.234434447
# launched image ingestion pipeline 5fcecca5-099e-4600-8d86-8d0c6ee875c6 on key dcm25/vpu0-0a/full/2021-05-25_20-09-16.697196006_66_998.061499814
# launched image ingestion pipeline e2e81e5b-65e4-4b14-ba2c-2389377d218c on key dcm25/vpu0-0a/full/2021-05-25_15-24-50.952116115_60_1136.219700467
# launched image ingestion pipeline 3f2bd5f6-39c1-4c28-8a6f-0cad1650c37f on key dcm25/vpu0-0a/full/2021-05-26_20-06-32.679531947_72_974.866130955
# launched image ingestion pipeline 24193591-3ad1-4a47-823f-e4b76ba17d9c on key dcm25/vpu0-0a/full/2021-05-25_15-22-48.490092451_60_1013.757676835
# launched image ingestion pipeline 18cb220a-0450-4da3-9976-e09b37bed57d on key dcm25/vpu0-0a/full/2021-05-24_16-06-03.985114791_55_959.236162791
# launched image ingestion pipeline 3e27aef6-b26d-48b5-abb6-492bc92ae2b6 on key dcm25/vpu0-0a/full/2021-05-19_20-59-07.321747011_42_513.741861411
# launched image ingestion pipeline f663af88-4d0e-4fd3-86d1-7c1d3a3c45fb on key dcm25/vpu0-0a/full/2021-05-24_21-29-04.964876173_58_1615.440277549
# launched image ingestion pipeline 2d1d3569-7afe-4bc1-8b25-75f2d1673161 on key dcm25/vpu0-0a/full/2021-05-27_19-50-51.822237669_81_348.041480068
# launched image ingestion pipeline 9dca63cc-5bca-407b-b2d2-d4c262ac4805 on key dcm25/vpu0-0a/full/2021-05-27_20-13-33.137049306_81_1709.356291674
# launched image ingestion pipeline 30a65d92-81a3-4352-b9f2-ff03577be567 on key dcm25/vpu0-0a/full/2021-05-26_21-47-18.715134336_73_523.106433344
# launched image ingestion pipeline 7321577f-e82e-4be6-bbab-92d162820354 on key dcm25/vpu0-0a/full/2021-05-25_16-15-37.436817978_61_1094.680291418
# launched image ingestion pipeline fc622e49-d149-467d-baca-c2b8c6110e87 on key dcm25/vpu0-0a/full/2021-05-27_16-17-39.013818455_77_1331.394205015
# launched image ingestion pipeline 4dd7d4a0-24a2-4890-9164-9036b5485bc9 on key dcm25/vpu0-0a/full/2021-05-27_15-10-40.892883383_76_1356.297946615
# launched image ingestion pipeline 1717feb7-41bb-4271-8442-c21496cb3e08 on key dcm25/vpu0-0a/full/2021-05-25_15-13-45.989482083_60_471.257066563
# launched image ingestion pipeline 665acb89-5b74-4502-8619-aef1a6d7e67c on key dcm25/vpu0-0a/full/2021-05-26_22-05-04.244104529_73_1588.635403473
# launched image ingestion pipeline 3659459d-d340-44d1-9673-d4656a092be0 on key dcm25/vpu0-0a/full/2021-05-19_21-44-54.988858317_42_3261.408972333
# launched image ingestion pipeline 4900c281-1ed2-4900-b4df-531c3b0c9386 on key dcm25/vpu0-0a/full/2021-05-30_15-33-05.284975169_86_865.497447905
# launched image ingestion pipeline 3d5c8b37-db71-43a1-b471-b5b88673e78f on key dcm25/vpu0-0a/full/2021-05-27_19-12-27.846690168_80_910.145858104
# launched image ingestion pipeline e2c8bd69-fe44-4d13-92c3-dd315d6c8e2b on key dcm25/vpu0-0a/full/2021-05-25_16-18-41.204737920_61_1278.448211200
# launched image ingestion pipeline 14e8aa89-ba25-4375-9db8-1ea4facec80d on key dcm25/vpu0-0a/full/2021-05-30_15-23-52.075212340_86_312.287684884
# launched image ingestion pipeline 4417afa6-8acf-43a5-a6e2-26adbdf6aedc on key dcm25/vpu0-0a/full/2021-05-24_16-34-33.020146923_55_2668.271194826
# launched image ingestion pipeline b122f6d4-8fdf-4337-8dc6-53a450e152f8 on key dcm25/vpu0-0a/full/2021-05-27_21-01-49.168039292_82_995.356454300
# launched image ingestion pipeline 524db85a-a7fc-4a29-baa2-fdb6b025ecb4 on key dcm25/vpu0-0a/full/2021-05-20_18-28-57.663498620_45_1512.898673852
# launched image ingestion pipeline a90870e2-bac7-40dc-8b17-a269933b0dba on key dcm25/vpu0-0a/full/2021-05-30_18-48-50.052755661_87_1478.187825069
# launched image ingestion pipeline fbbf2a6f-3005-404d-adac-e34d65c983b4 on key dcm25/vpu0-0a/full/2021-05-26_23-12-48.956603770_74_1952.184117626
# launched image ingestion pipeline 88bbd80b-a66c-4cdd-859a-63e932d910b4 on key dcm25/vpu0-0a/full/2021-05-20_22-31-56.112750794_49_1029.318222570
# launched image ingestion pipeline acc4beff-4861-4681-99d0-81982c9e0384 on key dcm25/vpu0-0a/full/2021-05-27_16-15-50.545000529_77_1222.925387185
# launched image ingestion pipeline af54b484-c783-4219-abd3-fc673723890a on key dcm25/vpu0-0a/full/2021-05-24_16-10-51.229767532_55_1246.480815468
# launched image ingestion pipeline e3a66e13-5e3e-4be2-a92c-de87139e59b7 on key dcm25/vpu0-0a/full/2021-05-27_17-11-58.343149544_78_630.531207592
# launched image ingestion pipeline 68aede97-252c-4dd6-9c58-405ab3b06efd on key dcm25/vpu0-0a/full/2021-05-25_20-14-58.472920763_66_1339.837224379
# launched image ingestion pipeline dd9bc785-5ee7-4afd-a707-4eb7e282ab81 on key dcm25/vpu0-0a/full/2021-05-21_15-50-52.081506291_53_1597.293910835
# launched image ingestion pipeline 2c75d4f3-e971-496a-a1f8-c65c9363d945 on key dcm25/vpu0-0a/full/2021-05-19_21-24-27.686229843_42_2034.106344115
# launched image ingestion pipeline 3d534722-9282-4dc0-8773-6970ad9e7cc0 on key dcm25/vpu0-0a/full/2021-05-27_23-05-30.847079302_84_1603.140443110
# launched image ingestion pipeline 0eb05fe0-2fed-4f03-adca-a415314efc17 on key dcm25/vpu0-0a/full/2021-05-21_15-44-42.655691942_53_1227.868096454
# launched image ingestion pipeline dc2e3071-b9b2-422e-b440-4247a6c231a4 on key dcm25/vpu0-0a/full/2021-05-27_21-04-06.763659943_82_1132.952074823
# launched image ingestion pipeline fa496715-6a2a-4650-b801-a26a21988deb on key dcm25/vpu0-0a/full/2021-05-27_19-09-43.195361530_80_745.494529594
# launched image ingestion pipeline 57721b5d-26b4-40ac-bc6f-ed9b9f7b31a9 on key dcm25/vpu0-0a/full/2021-05-30_18-30-26.755772595_87_374.890842003
# launched image ingestion pipeline 365c54c7-cefa-4a10-9505-eebfa80f6926 on key dcm25/vpu0-0a/full/2021-05-25_19-20-05.791221816_65_1484.004640376
# launched image ingestion pipeline fc359d54-4471-4a38-8833-092bae098b03 on key dcm25/vpu0-0a/full/2021-05-26_13-52-54.559477153_69_938.786598273
# launched image ingestion pipeline d93f090f-bcbf-490d-9ee0-37c9eb548b46 on key dcm25/vpu0-0a/full/2021-05-25_20-21-47.316108254_66_1748.680412190
# launched image ingestion pipeline 22a196e4-54f5-4c20-8016-4d3c76c3eff8 on key dcm25/vpu0-0a/full/2021-05-26_13-18-08.342904932_68_2412.585975780
# launched image ingestion pipeline 2b350da3-5c96-4b10-aa2a-7d8d53bbe5be on key dcm25/vpu0-0a/full/2021-05-20_20-33-01.606776871_47_1946.867821895
# launched image ingestion pipeline 4d74fc74-813c-42e5-9306-2ebb48e976e1 on key dcm25/vpu0-0a/full/2021-05-25_15-10-53.342018344_60_298.609602760
# launched image ingestion pipeline 26dfb650-bd78-4f05-b57a-1399e45cf0aa on key dcm25/vpu0-0a/full/2021-05-26_13-07-15.692006265_68_1759.935076985
# launched image ingestion pipeline 47e38f74-caaf-497d-ac46-433461effbfa on key dcm25/vpu0-0a/full/2021-05-26_21-59-26.901072498_73_1251.292371314
# launched image ingestion pipeline 711ea19d-5ae1-4bfe-a3ec-d03b6d494220 on key dcm25/vpu0-0a/full/2021-05-25_19-04-11.962926344_65_530.176345032
# launched image ingestion pipeline e2be8ad4-81d0-4794-b494-a5e0dcb80ed3 on key dcm25/vpu0-0a/full/2021-05-20_21-42-53.596103707_48_1518.985254875
# launched image ingestion pipeline a12aedb3-40ad-4678-8e15-6ec799eeea21 on key dcm25/vpu0-0a/full/2021-05-25_20-04-23.458972909_66_704.823276685
# launched image ingestion pipeline 61a8ad10-c21c-4111-b32d-004b2d2a0147 on key dcm25/vpu0-0a/full/2021-05-27_15-08-31.392413027_76_1226.797476355
# launched image ingestion pipeline 3f499db5-7387-4f9e-bfc0-5b0de08e1ecc on key dcm25/vpu0-0a/full/2021-05-27_22-43-06.381006891_84_258.674370603
# launched image ingestion pipeline fbd14600-9b33-4a6c-9a1b-4ba2a7fd6e79 on key dcm25/vpu0-0a/full/2021-05-21_14-50-53.365035040_52_2015.649396192
# launched image ingestion pipeline 7c301a2c-8d36-44c5-96dd-dd572fd65e3e on key dcm25/vpu0-0a/full/2021-05-27_21-06-11.318065417_82_1257.506480169
# launched image ingestion pipeline 314b3ec3-e62f-4282-bc3e-9797cfc3b9e7 on key dcm25/vpu0-0a/full/2021-05-21_14-36-30.893788120_52_1153.178148984
# launched image ingestion pipeline bfe703d9-4a84-4559-90f0-50d79f20a578 on key dcm25/vpu0-0a/full/2021-05-24_16-17-40.902720900_55_1656.153768804
# launched image ingestion pipeline f77af60e-785a-4ea8-80dd-21fa866e4569 on key dcm25/vpu0-0a/full/2021-05-27_22-47-16.364628910_84_508.657992590
# launched image ingestion pipeline 0b050a51-6aa0-4cb6-ac19-f87e761f5050 on key dcm25/vpu0-0a/full/2021-05-20_16-58-39.033865994_44_654.266225674
# launched image ingestion pipeline b649dde9-88fd-4eaf-bf45-e36d8d70d644 on key dcm25/vpu0-0a/full/2021-05-26_21-56-47.250342318_73_1091.641641326
# launched image ingestion pipeline 2f9cefcb-da5b-4dbb-a90c-6f6679f0c323 on key dcm25/vpu0-0a/full/2021-05-24_18-00-16.072215530_56_913.371367850
# launched image ingestion pipeline 89db8e1d-1116-4543-869a-69e718a51b5e on key dcm25/vpu0-0a/full/2021-05-27_19-06-01.305676664_80_523.604844856
# launched image ingestion pipeline e87988d6-ad76-424d-8be9-5b7b11712231 on key dcm25/vpu0-0a/full/2021-05-21_15-48-14.474435030_53_1439.686839638
# launched image ingestion pipeline cccc315a-2085-44e8-be1b-4be608707201 on key dcm25/vpu0-0a/full/2021-05-20_18-40-14.733195005_45_2189.968370301
# launched image ingestion pipeline 0ee4157e-d173-4100-b52f-a34bc3665c47 on key dcm25/vpu0-0a/full/2021-05-26_23-03-54.791870088_74_1418.019383688
# launched image ingestion pipeline 2423ab40-3eb8-4382-9cc7-fdbc84d2a331 on key dcm25/vpu0-0a/full/2021-05-24_21-33-17.039713456_58_1867.515114832
# launched image ingestion pipeline 23a57467-8781-4662-ad77-ec88c7725c58 on key dcm25/vpu0-0a/full/2021-05-26_13-04-27.973424931_68_1592.216495683
# launched image ingestion pipeline 72a687d8-d94f-4286-8e17-1e466d7dca90 on key dcm25/vpu0-0a/full/2021-05-27_17-19-27.149154933_78_1079.337213141
# launched image ingestion pipeline dabb398d-db2d-4118-8ab4-e64fe1ede2c8 on key dcm25/vpu0-0a/full/2021-05-21_14-41-17.020152432_52_1439.304513424
# launched image ingestion pipeline 1eb191f7-3015-4eee-944f-0ba25e1bfaaa on key dcm25/0/full/2021-04-28_21-21-32.273473125_30_69.589253635
# launched image ingestion pipeline b3abf89c-1beb-43c3-b0b2-0abded6aa39b on key dcm25/vpu0-0a/full/2021-05-27_19-23-38.570305671_80_1580.869473703
# launched image ingestion pipeline fa899618-e267-4f79-aac3-467bf1116f89 on key dcm25/vpu0-0a/full/2021-05-26_21-51-04.625254288_73_749.016553136
# launched image ingestion pipeline 65efc7d4-dcc3-4d4f-a0ea-423acc9bbe30 on key dcm25/vpu0-0a/full/2021-05-27_16-02-50.404739472_77_442.785125807
# launched image ingestion pipeline eded06f9-bdd6-4665-9289-2873e65631ea on key dcm25/vpu0-0a/full/2021-05-27_15-02-40.988241623_76_876.393304727
# launched image ingestion pipeline e8e906cd-44e4-499c-8ee4-f0417b21c30c on key dcm25/vpu0-0a/full/2021-05-26_13-15-33.712343630_68_2257.955414318
# launched image ingestion pipeline 7cbb3f73-a1f6-48b9-b606-d1ee9fa4bbff on key dcm25/vpu0-0a/full/2021-05-25_20-06-52.102328259_66_853.466632067
# launched image ingestion pipeline 59b033f1-9a75-48e6-bf25-6a1deb180c7c on key dcm25/vpu0-0a/full/2021-05-19_21-32-49.798138161_42_2536.218252273
# launched image ingestion pipeline 9572fd6d-3153-475b-b9b7-793a6097ab41 on key dcm25/0/full/2021-04-28_20-53-32.228790278_26_69.254582143
# launched image ingestion pipeline fdf0106b-c006-4d9c-b09f-961bcf788c01 on key dcm25/vpu0-0a/full/2021-05-24_18-03-23.815075072_56_1101.114227232
# launched image ingestion pipeline c056f343-7da2-49c2-9d90-dace2620100c on key dcm25/vpu0-0a/full/2021-05-20_20-32-06.393166065_47_1891.654211153
# launched image ingestion pipeline 2589e22c-9b9b-4d91-8beb-bd64806bab42 on key dcm25/vpu0-0a/full/2021-05-24_16-20-54.732055901_55_1849.983103581
# launched image ingestion pipeline 232daa7e-e69e-4ac3-a1cc-a0197ea59ef2 on key dcm25/vpu0-0a/full/2021-05-26_12-54-27.354146096_68_991.597216624
# launched image ingestion pipeline 7139cc91-e481-4637-824a-a537131ac275 on key dcm25/vpu0-0a/full/2021-05-24_18-23-51.974012978_56_2329.273165202
# launched image ingestion pipeline 2567ac12-55ae-4852-b54c-b73fe026485c on key dcm25/vpu0-0a/full/2021-05-24_17-57-45.463799052_56_762.762951436
# launched image ingestion pipeline eb5f0965-4a6c-41ac-8417-826c7fb5483f on key dcm25/vpu0-0a/full/2021-05-20_17-20-46.518590584_44_1981.750950264
# launched image ingestion pipeline 03e0b30c-dc45-46d3-bbe9-bf08b089e592 on key dcm25/vpu0-0a/full/2021-05-24_18-18-24.610281644_56_2001.909433868
# launched image ingestion pipeline 0c6e2480-55fe-411f-b355-920e1a8be411 on key dcm25/vpu0-0a/full/2021-05-26_13-55-21.163622258_69_1085.390743378
# launched image ingestion pipeline c14129f9-7811-4295-8f8f-7488e1b11bec on key dcm25/vpu0-0a/full/2021-05-30_15-27-00.856734218_86_501.069207082
# launched image ingestion pipeline 5ebbaa60-b256-4ec6-bc33-face2146d12c on key dcm25/vpu0-0a/full/2021-05-20_18-23-04.254547034_45_1159.489722362
# launched image ingestion pipeline 037d97b6-a6b7-4eaa-ba4e-32b019d07071 on key dcm25/vpu0-0a/full/2021-05-27_16-09-31.044517872_77_843.424904496
# launched image ingestion pipeline 28c262d9-bcb4-4d7f-a12c-65737c47893f on key dcm25/vpu0-0a/full/2021-05-24_18-06-05.699058158_56_1262.998210382
# launched image ingestion pipeline 5be9392b-63d1-40e8-b385-0c1e20a6071f on key dcm25/vpu0-0a/full/2021-05-25_16-23-17.366788843_61_1554.610261867
# launched image ingestion pipeline 112ade75-4f19-4059-a28a-c8ef8c38b22e on key dcm25/vpu0-0a/full/2021-05-20_17-18-44.019867178_44_1859.252226986
# launched image ingestion pipeline a0f3a804-d174-4960-a244-2b3306eccbf1 on key dcm25/vpu0-0a/full/2021-05-20_17-07-30.313375454_44_1185.545734942
# launched image ingestion pipeline f5e5a7c7-7a21-4fd9-aa03-f7ad3bd7759e on key dcm25/vpu0-0a/full/2021-05-26_12-50-16.402001883_68_740.645072731
# launched image ingestion pipeline b49df082-3d72-4857-a509-855e085af8bf on key dcm25/vpu0-0a/full/2021-05-25_19-14-01.314350266_65_1119.527768826
# launched image ingestion pipeline a4ae5bb9-433a-430a-aed1-0c4607846010 on key dcm25/vpu0-0a/full/2021-05-24_21-11-27.736236798_58_558.211638110
# launched image ingestion pipeline 02fb58f9-6031-44b3-855c-6b488021dcb2 on key dcm25/vpu0-0a/full/2021-05-24_16-01-27.768006013_55_683.019053821
# launched image ingestion pipeline 94a81649-674e-4aea-af74-b647aa3e6d44 on key dcm25/vpu0-0a/full/2021-05-20_17-25-24.027220651_44_2259.259551529
# launched image ingestion pipeline e08bd6a8-fe7d-491d-ad59-554118cf687c on key dcm25/vpu0-0a/full/2021-05-20_18-31-52.383233021_45_1687.618408285
# launched image ingestion pipeline b055e00e-60c9-41f2-961e-eb99cfdbe6e3 on key dcm25/vpu0-0a/full/2021-05-26_21-53-03.144489545_73_867.535788393
# launched image ingestion pipeline df87947a-5752-42cf-893e-2f5275133e7d on key dcm25/vpu0-0a/full/2021-05-26_22-55-21.686083913_74_904.913597577
# launched image ingestion pipeline 5af73afc-896f-46a1-8936-443de5768163 on key dcm25/vpu0-0a/full/2021-05-24_21-13-43.302940004_58_693.778341348
# launched image ingestion pipeline b5f48c7e-22f3-4dba-8203-4a0d557662cd on key dcm25/vpu0-0a/full/2021-05-20_20-09-40.656947121_47_545.917992113
# launched image ingestion pipeline c4bd80e7-d16b-44f1-87ef-d9abc434ec62 on key dcm25/vpu0-0a/full/2021-05-26_20-11-00.653668533_72_1242.840267317
# launched image ingestion pipeline abe87079-4fb5-4c69-a2a3-b5e75389816c on key dcm25/vpu0-0a/full/2021-05-26_23-15-43.711161128_74_2126.938674760
# launched image ingestion pipeline 2357222b-3c47-49e3-8f86-b26ba3b5b3a3 on key dcm25/vpu0-0a/full/2021-05-20_17-30-53.365106212_44_2588.597465764
# launched image ingestion pipeline fad91e9b-8f84-4a17-a8db-a415fc6fa010 on key dcm25/vpu0-0a/full/2021-05-26_22-53-16.146696457_74_779.374209897
# launched image ingestion pipeline 91bc5c99-c02c-4875-a627-6653e0275bfa on key dcm25/vpu0-0a/full/2021-05-19_21-08-30.532553790_42_1076.952667934
# launched image ingestion pipeline 59fc7c31-4983-4bab-9d8d-723f01d1788c on key dcm25/vpu0-0a/full/2021-05-30_18-42-40.622453757_87_1108.757523165
# launched image ingestion pipeline 2607630a-b14a-4dc6-af99-9cff2f89339b on key dcm25/vpu0-0a/full/2021-05-21_15-53-40.793985291_53_1766.006389931
# launched image ingestion pipeline 82bd8940-adb8-4ee2-9ab8-4aa5a6801568 on key dcm25/vpu0-0a/full/2021-05-20_18-19-29.395751858_45_944.630927090
# launched image ingestion pipeline 75672394-5866-4899-aac7-a0baea56e86a on key dcm25/vpu0-0a/full/2021-05-26_19-56-31.355373059_72_373.541972035
# launched image ingestion pipeline d5fd043d-ba3f-4b58-b5fd-0fda14bf1680 on key dcm25/vpu0-0a/full/2021-05-27_20-02-50.539406174_81_1066.758648510
# launched image ingestion pipeline 7122dac8-177e-4b12-963c-5aa1f4cba1a1 on key dcm25/vpu0-0a/full/2021-05-27_19-53-46.511922472_81_522.731164552
# launched image ingestion pipeline 11c04fcd-aa2b-44bd-b151-36dfcfba17c8 on key dcm25/vpu0-0a/full/2021-05-27_22-59-46.391581194_84_1258.684944842
# launched image ingestion pipeline 43bb63b6-9f16-4b7f-bb47-275c8b29155b on key dcm25/vpu0-0a/full/2021-05-19_21-39-11.392685581_42_2917.812799757
# launched image ingestion pipeline 26ee020f-c8ad-49d0-8638-22eece299c2c on key dcm25/vpu0-0a/full/2021-05-20_17-14-13.946852562_44_1589.179212178
# launched image ingestion pipeline f16ea421-5e5f-4c17-8490-e9b1b7473816 on key dcm25/vpu0-0a/full/2021-05-26_14-08-27.275254849_69_1871.502375617
# launched image ingestion pipeline c5563047-fd4f-4534-88d0-e4ebdbdc9ff4 on key dcm25/vpu0-0a/full/2021-05-25_17-02-07.006086966_62_244.298109526
# launched image ingestion pipeline ec7c2425-bf5e-491d-ae55-241b50bbee0a on key dcm25/vpu0-0a/full/2021-05-27_20-50-38.423789322_82_324.612203882
# launched image ingestion pipeline c55ddfcf-f9c6-40bb-9d0c-1e7755ff3527 on key dcm25/vpu0-0a/full/2021-05-27_14-57-07.655156540_76_543.060219932
# launched image ingestion pipeline ff5dc5c2-2fa4-40e2-a0ae-565a579448a9 on key dcm25/vpu0-0a/full/2021-05-25_16-20-33.685637512_61_1390.929110696
# launched image ingestion pipeline 3210c560-7a50-4f6f-92bb-9452880ba545 on key dcm25/vpu0-0a/full/2021-05-25_16-25-25.914424633_61_1683.157897945
# launched image ingestion pipeline 055553cd-2abd-4d12-829a-8ad03770524c on key dcm25/vpu0-0a/full/2021-05-27_16-06-54.399242944_77_686.779629408
# launched image ingestion pipeline 6523f2d7-3663-4f6b-b695-1bdba3e32257 on key dcm25/vpu0-0a/full/2021-05-20_22-28-01.116321528_49_794.321793432
# launched image ingestion pipeline 566f9228-5264-4903-b15f-6562f28bf494 on key dcm25/vpu0-0a/full/2021-05-27_17-31-49.120599768_78_1821.308657912
# launched image ingestion pipeline 8b47c5e2-691e-4d9d-a9e7-378b2f126b29 on key dcm25/vpu0-0a/full/2021-05-20_18-12-58.663412592_45_553.898587888
# launched image ingestion pipeline 177580ba-5eca-4156-a64f-9dd20cc0d0c2 on key dcm25/vpu0-0a/full/2021-05-20_21-29-58.656412059_48_744.045562971
# launched image ingestion pipeline 66b89b68-c1b7-41a8-bb4f-6c2faac0d950 on key dcm25/vpu0-0a/full/2021-05-27_17-28-30.331184683_78_1622.519242699
# launched image ingestion pipeline c0de7699-9a9c-45b3-8eb5-344a6896b8e6 on key dcm25/vpu0-0a/full/2021-05-20_20-36-23.591054275_47_2148.852099299
# launched image ingestion pipeline 1ac22f69-70af-4a59-8bd3-616d92accde6 on key dcm25/vpu0-0a/full/2021-05-27_19-03-28.676901130_80_370.976069226
# launched image ingestion pipeline c6397d72-3370-4ffc-89b5-6a3378d2195f on key dcm25/vpu0-0a/full/2021-05-21_14-44-29.905309276_52_1632.189670268
# launched image ingestion pipeline 61a5aca1-69e6-41a8-be60-e7f30efb9770 on key dcm25/vpu0-0a/full/2021-05-25_15-18-27.178181943_60_752.445766359
# launched image ingestion pipeline c8dfa372-58ab-452a-af8e-4f936f831c36 on key dcm25/vpu0-0a/full/2021-05-26_14-03-15.012485640_69_1559.239606664
# launched image ingestion pipeline f2f5ded5-ebbf-4582-a2fb-66271f78ae88 on key dcm25/vpu0-0a/full/2021-05-25_19-15-53.782014593_65_1231.995433153
# launched image ingestion pipeline 92114a0a-5e61-4c5f-ae66-71449eb20596 on key dcm25/vpu0-0a/full/2021-05-24_21-19-42.693783550_58_1053.169184894
# launched image ingestion pipeline c564355f-a8c5-445c-8de2-688f4632a748 on key dcm25/vpu0-0a/full/2021-05-27_16-21-12.871716203_77_1545.252102827
# launched image ingestion pipeline 1483faa0-9f4a-4c47-b82f-2553301201df on key dcm25/vpu0-0a/full/2021-05-21_14-33-16.069478766_52_958.353839694
# launched image ingestion pipeline 8b17d4d4-10f5-4e8c-861e-81d49042b7b2 on key dcm25/vpu0-0a/full/2021-05-20_18-26-03.968480669_45_1339.203655901
# launched image ingestion pipeline 0cdb54b3-4086-4798-8a4b-4229de70a566 on key dcm25/vpu0-0a/full/2021-05-30_15-37-01.190288639_86_1101.402761183
# launched image ingestion pipeline 1f280ab6-d85f-4e74-b0f6-b0a6a5ae4ffe on key dcm25/vpu0-0a/full/2021-05-20_21-26-09.455249278_48_514.844400318
# launched image ingestion pipeline 155cb4df-5061-4420-9830-adbf1c628bd5 on key dcm25/vpu0-0a/full/2021-05-24_18-11-06.915519482_56_1564.214671738
# launched image ingestion pipeline 6c651ba7-a232-4005-a013-68bf6e007a4d on key dcm25/vpu0-0a/full/2021-05-27_20-13-12.056732068_81_1688.275974212
# launched image ingestion pipeline 9a207849-ea73-467b-b800-6c57a2441cfd on key dcm25/vpu0-0a/full/2021-05-21_15-41-45.940019037_53_1051.152423613
# launched image ingestion pipeline e097b4ea-c55f-4412-956a-213e2b8bc816 on key dcm25/vpu0-0a/full/2021-05-19_21-49-51.180283350_42_3557.600397526
# launched image ingestion pipeline 1753cce8-faea-4751-9635-f3105ab9b35a on key dcm25/vpu0-0a/full/2021-05-27_23-02-44.162319551_84_1436.455683103
# launched image ingestion pipeline ff4d7fce-10c1-4f97-bbe5-ebc19adbe7e5 on key dcm25/vpu0-0a/full/2021-05-27_20-48-32.894669448_82_199.083084360
# launched image ingestion pipeline 2edd3045-0a6e-4979-a60d-74dec519e070 on key dcm25/vpu0-0a/full/2021-05-20_21-23-03.734827220_48_329.123978388
# launched image ingestion pipeline c6883d0e-01ff-4c57-ac84-25e6da461096 on key dcm25/vpu0-0a/full/2021-05-27_19-18-31.310050236_80_1273.609218236
# launched image ingestion pipeline 8476431b-7655-468e-aab4-f1f503829382 on key dcm25/vpu0-0a/full/2021-05-27_20-59-53.674482248_82_879.862897320
# launched image ingestion pipeline 45386262-262c-4de2-a2b5-0e37ea0229cd on key dcm25/vpu0-0a/full/2021-05-27_20-09-35.206931850_81_1471.426174058
# launched image ingestion pipeline 73585b00-468e-4be5-a30b-578b9e21e475 on key dcm25/vpu0-0a/full/2021-05-25_18-59-05.763058991_65_223.976477647
# launched image ingestion pipeline 4265a270-845f-4767-879f-9dda799c5e29 on key dcm25/vpu0-0a/full/2021-05-20_20-13-52.641151367_47_797.902196327
# launched image ingestion pipeline 452006aa-80bf-4507-9ab2-ae39ffd113ac on key dcm25/vpu0-0a/full/2021-05-24_18-15-18.862168459_56_1816.161320587
# launched image ingestion pipeline 1322d598-aee3-47a4-a50b-ce2698ce5e9b on key dcm25/vpu0-0a/full/2021-05-27_15-05-35.714088066_76_1051.119151362
# launched image ingestion pipeline a2b337c2-bae7-48a0-a986-245ef9fd105b on key dcm25/vpu0-0a/full/2021-05-30_18-33-38.550312295_87_566.685381415
# launched image ingestion pipeline 9b6b11ad-9453-4a57-b311-bd38364aeae0 on key dcm25/vpu0-0a/full/2021-05-27_16-04-50.891641250_77_563.272027810
# launched image ingestion pipeline e1c081b2-956f-4e9b-85d1-4bbbf08964fc on key dcm25/vpu0-0a/full/2021-05-27_17-23-09.004611076_78_1301.192669124
# launched image ingestion pipeline 39668f50-adca-4f31-ad15-eb237209182f on key dcm25/vpu0-0a/full/2021-05-20_22-29-53.588844786_49_906.794316658
# launched image ingestion pipeline 3900528e-62e3-4dee-bdcd-c4f944e66be5 on key dcm25/vpu0-0a/full/2021-05-25_15-21-40.178139148_60_945.445723660
# launched image ingestion pipeline 684b537a-1511-43d4-afbe-a7256d450c36 on key dcm25/vpu0-0a/full/2021-05-24_16-14-28.078631900_55_1463.329679836
# launched image ingestion pipeline 971926f1-4c75-44e0-aa2d-8fdb7c79147d on key dcm25/vpu0-0a/full/2021-05-26_22-48-12.958362317_74_476.185876077
# launched image ingestion pipeline 6b5e6af2-1047-4e54-a388-096faa7f9e43 on key dcm25/vpu0-0a/full/2021-05-25_19-01-30.333931869_65_368.547350269
# launched image ingestion pipeline cdb0b6fd-601d-4e57-9240-179a7489534d on key dcm25/vpu0-0a/full/2021-05-27_20-07-30.679845262_81_1346.899087598
# launched image ingestion pipeline 7fc9e465-79d7-474d-8e55-b2a480c937d2 on key dcm25/vpu0-0a/full/2021-05-26_22-01-13.381298416_73_1357.772597360
# launched image ingestion pipeline 36d3e2ab-a72c-4553-9325-4c48e5a76db6 on key dcm25/vpu0-0a/full/2021-05-24_16-24-50.699240066_55_2085.950288002
# launched image ingestion pipeline 0f003676-bf64-490b-97d3-70964edfd50d on key dcm25/vpu0-0a/full/2021-05-26_13-12-51.985823691_68_2096.228894539
# launched image ingestion pipeline 1b92544a-14bb-46c5-ab91-1e9bab9aaef2 on key dcm25/vpu0-0a/full/2021-05-26_23-09-00.016448552_74_1723.243962024
# launched image ingestion pipeline 2b54a463-3c37-4bf8-ac74-385dded1cee5 on key dcm25/vpu0-0a/full/2021-05-20_21-39-37.837592054_48_1323.226743190
# launched image ingestion pipeline 85169a2f-716b-45ef-8f97-2645707a7e0e on key dcm25/vpu0-0a/full/2021-05-30_18-51-19.663968344_87_1627.799037752
# launched image ingestion pipeline 02a907ee-c598-4805-989a-80f4edd8a91e on key dcm25/vpu0-0a/full/2021-05-20_21-36-50.197401016_48_1155.586551928
# launched image ingestion pipeline 33b5bf85-e2b4-4dca-b340-b2e5bf09b206 on key dcm25/vpu0-0a/full/2021-05-21_14-54-20.162571062_52_2222.446932054
# launched image ingestion pipeline bf8a9def-f6f1-4c0a-883a-32b71bcf6dd8 on key dcm25/vpu0-0a/full/2021-05-25_20-24-34.012252758_66_1915.376556566
# launched image ingestion pipeline 80f0219b-efb6-4891-9066-0b3b65ffb162 on key dcm25/vpu0-0a/full/2021-05-20_22-34-04.658216921_49_1157.863688921
# launched image ingestion pipeline 35e869c1-81bd-490e-b53f-8154c05e97d1 on key dcm25/vpu0-0a/full/2021-05-20_18-37-53.156860072_45_2048.392035432
# launched image ingestion pipeline 73a253ad-7c5b-4b90-b1cd-46da75ceabfa on key dcm25/vpu0-0a/full/2021-05-26_20-15-43.779568722_72_1525.966167570
# launched image ingestion pipeline 9915f88f-aa17-4a1a-a22c-9a20c83b736e on key dcm25/vpu0-0a/full/2021-05-20_21-45-32.222081884_48_1677.611233244
# launched image ingestion pipeline cfb66586-2a6c-406b-aa00-d5c36b8e02ae on key dcm25/vpu0-0a/full/2021-05-27_20-55-49.686756638_82_635.875171262
# launched image ingestion pipeline 23b5525e-dea2-40f3-9f9f-23881e70afe7 on key dcm25/vpu0-0a/full/2021-05-19_21-17-09.554831091_42_1595.974945299
# launched image ingestion pipeline e5435ae6-f6f9-4e65-9991-9c3ea4037fb3 on key dcm25/vpu0-0a/full/2021-05-26_13-46-34.128971260_69_558.356092124
# launched image ingestion pipeline 805523fa-247a-4b34-8a15-a574984cff1a on key dcm25/vpu0-0a/full/2021-05-24_16-30-26.027686573_55_2421.278734445
# launched image ingestion pipeline 158117c2-a1e4-499c-8d1f-c1f184b67f93 on key dcm25/vpu0-0a/full/2021-05-21_14-48-22.769388751_52_1865.053749615
# launched image ingestion pipeline 9433cef3-76fb-4021-adea-e98a10606504 on key dcm25/vpu0-0a/full/2021-05-30_15-42-43.566825201_86_1443.779297873
# launched image ingestion pipeline 4f8253ea-ea30-45fb-a736-0ec6e9fd4579 on key dcm25/vpu0-0a/full/2021-05-30_18-53-58.275741102_87_1786.410810318
# launched image ingestion pipeline e4f1f3d3-36e3-40ab-90e2-d4a5c8a8e879 on key dcm25/vpu0-0a/full/2021-05-26_23-06-07.320750168_74_1550.548263992
# launched image ingestion pipeline 261601ed-5f72-46bf-af46-2df99b16b0c2 on key dcm25/vpu0-0a/full/2021-05-20_20-23-14.106559707_47_1359.367604891
# launched image ingestion pipeline 3a1d922d-e8d3-43ee-9028-a7d298ef844b on key dcm25/vpu0-0a/full/2021-05-25_16-04-52.521699070_61_449.765172382
# launched image ingestion pipeline 7462beff-e662-49d5-bb29-6de0d3da9b76 on key dcm25/vpu0-0a/full/2021-05-20_21-33-18.399662874_48_943.788814266
# launched image ingestion pipeline cabfd4f8-8b3e-4420-8cbb-d75d8c514092 on key dcm25/vpu0-0a/full/2021-05-27_23-12-51.561990669_84_2043.855354220
# launched image ingestion pipeline b2fc61dd-e442-4699-bff1-28385207bd20 on key dcm25/vpu0-0a/full/2021-05-27_22-49-43.959297199_84_656.252660783
# launched image ingestion pipeline 41f26072-d4ad-44fe-b2e0-dcc5084cc970 on key dcm25/vpu0-0a/full/2021-05-26_14-00-12.291057432_69_1376.518178456
# launched image ingestion pipeline ec7a65c3-d40e-4c91-b63d-1ff1ff2a33ec on key dcm25/vpu0-0a/full/2021-05-27_19-21-24.018677247_80_1446.317845407
# launched image ingestion pipeline feb550d1-d8a6-454f-8b79-a19dc918fbbf on key dcm25/vpu0-0a/full/2021-05-26_20-03-02.847859840_72_765.034458688
# launched image ingestion pipeline 35024394-ef2b-4fc2-92f2-f95d06091e1d on key dcm25/vpu0-0a/full/2021-05-20_17-10-54.150992703_44_1389.383352479
# launched image ingestion pipeline b79d9ad5-6ac0-4e0f-9aea-1548373f4372 on key dcm25/vpu0-0a/full/2021-05-24_21-24-01.718554292_58_1312.193955604
# launched image ingestion pipeline c5148ed5-c309-4604-84e4-7bed8f7b6a68 on key dcm25/vpu0-0a/full/2021-05-27_22-53-12.807173231_84_865.100536783
# launched image ingestion pipeline b23189c4-7bde-4ef3-af6c-263e4350a98f on key dcm25/vpu0-0a/full/2021-05-20_17-02-35.205405013_44_890.437764629
# launched image ingestion pipeline 715573f6-68f9-4ebb-be41-45eddc90a15d on key dcm25/vpu0-0a/full/2021-05-27_17-13-47.798340425_78_739.986398505
# launched image ingestion pipeline bd2c6ab7-004f-48d6-9910-1b3d8064da9c on key dcm25/vpu0-0a/full/2021-05-25_15-26-35.372247229_60_1240.639831709
# launched image ingestion pipeline 1a9a7e37-00f8-45e8-996e-a1b3193dd1c8 on key dcm25/vpu0-0a/full/2021-05-25_15-33-01.900297256_60_1627.167881640
# launched image ingestion pipeline 62028b6e-603c-4f4c-b981-e7735d09909a on key dcm25/vpu0-0a/full/2021-05-21_16-01-44.797329226_53_2250.009733898
# launched image ingestion pipeline 6cbf3220-2a4d-44b2-90a7-4b5f8c6147db on key dcm25/vpu0-0a/full/2021-05-26_20-31-58.479091300_72_2500.665690180
# launched image ingestion pipeline ebf263f0-8d70-4902-a2ca-d2dc68b243cc on key dcm25/vpu0-0a/full/2021-05-27_22-56-45.659168949_84_1077.952532565
# launched image ingestion pipeline e5ff8577-a778-4893-b405-27b74f3de1b9 on key dcm25/vpu0-0a/full/2021-05-30_18-45-37.286135789_87_1285.421205197
# launched image ingestion pipeline bc15ca54-b965-4e49-a829-18498ec38241 on key dcm25/vpu0-0a/full/2021-05-27_19-15-35.626054531_80_1097.925222691
# launched image ingestion pipeline fef2e49c-e7c7-4861-9889-c4c390307a27 on key dcm25/vpu0-0a/full/2021-05-27_19-58-56.610557081_81_832.829799385
# launched image ingestion pipeline 18770c47-0153-4bde-9f7a-f5503c307a24 on key dcm25/vpu0-0a/full/2021-05-20_17-29-29.022979135_44_2504.255338847
# launched image ingestion pipeline 0945c185-72f0-4bae-945a-9d828b11d9f8 on key dcm25/vpu0-0a/full/2021-05-25_19-17-53.272238487_65_1351.485657143
# launched image ingestion pipeline aecf51b2-ce13-489b-bc86-86d5e55e3bde on key dcm25/vpu0-0a/full/2021-05-25_16-12-18.280839051_61_895.524312331
# launched image ingestion pipeline a78de1cb-366b-4286-aa52-f668511a22d6 on key dcm25/vpu0-0a/full/2021-05-25_20-19-40.803911826_66_1622.168215602
# launched image ingestion pipeline f5211813-a8f2-4569-b2ec-535ec7f051d8 on key dcm25/0/full/2021-04-28_21-21-38.308496598_30_75.624277204
# launched image ingestion pipeline ae3fce2b-2d58-47b1-abd0-47b3a17fe846 on key dcm25/vpu0-0a/full/2021-05-25_15-22-41.422390597_60_1006.689975045
# launched image ingestion pipeline 9d9cef24-6eb5-4ed8-97f3-080c06f8b422 on key dcm25/vpu0-0a/full/2021-05-27_17-25-43.656106121_78_1455.844164201
# launched image ingestion pipeline 35ce8bce-e70f-4c9f-aef6-457c1a0758c7 on key dcm25/vpu0-0a/full/2021-05-25_16-27-52.525575451_61_1829.769048667
# launched image ingestion pipeline e854886e-6c57-4593-84c4-f0c9a669af94 on key dcm25/vpu0-0a/full/2021-05-24_21-26-21.308956597_58_1451.784357941
# launched image ingestion pipeline 156275ed-7046-4a91-aa05-69047dd22086 on key dcm25/vpu0-0a/full/2021-05-30_15-30-11.600962626_86_691.813435298
# launched image ingestion pipeline ee51fd0b-cf89-4490-91c9-ad1a72be0118 on key dcm25/vpu0-0a/full/2021-05-27_17-34-18.728105634_78_1970.916163682
# launched image ingestion pipeline dc12517d-ad70-40df-8c12-a4a6b21a281c on key dcm25/vpu0-0a/full/2021-05-21_14-29-30.828358551_52_733.112719511
# launched image ingestion pipeline ba941d4f-462c-4510-9445-fe46d9c027bd on key dcm25/vpu0-0a/full/2021-05-27_17-16-55.539204743_78_927.727262759
# launched image ingestion pipeline 33bd64c4-6f5d-4b13-baec-dec9858c2f37 on key dcm25/vpu0-0a/full/2021-05-30_15-47-43.942848791_86_1744.155321495
# launched image ingestion pipeline 847f2750-70d9-4637-9e84-7543e3569325 on key dcm25/vpu0-0a/full/2021-05-24_21-31-04.451493479_58_1734.926894823
# launched image ingestion pipeline c17bf1e3-5b49-43f3-8f4f-b8acf1bc7e48 on key dcm25/0/full/2021-04-21_01-55-48.015544334_17_127.707121298
# launched image ingestion pipeline b25faf04-3637-4faa-b13b-a2259b8cee56 on key dcm25/vpu0-0a/full/2021-05-26_21-49-05.144773186_73_629.536072002
# launched image ingestion pipeline 35b4219f-bba8-481c-9e3a-57b283c423d7 on key dcm25/vpu0-0a/full/2021-05-21_16-03-35.262876603_53_2360.475281307
# launched image ingestion pipeline abe177bf-3f8c-4792-bfa9-6c57426dfd47 on key dcm25/vpu0-0a/full/2021-05-26_12-58-31.601029171_68_1235.844099923
# launched image ingestion pipeline efef2f61-d71a-4b0a-a1a8-794bd334872a on key dcm25/vpu0-0a/full/2021-05-27_20-53-37.135116175_82_503.323531087
# launched image ingestion pipeline edfc2f8c-2e21-4385-9bfb-6c78784c29aa on key dcm25/vpu0-0a/full/2021-05-26_20-20-45.934501010_72_1828.121100050
# launched image ingestion pipeline f8840fdd-e01a-46ec-a5d2-4ef75789d447 on key dcm25/vpu0-0a/full/2021-05-26_19-59-41.080136797_72_563.266735645
# launched image ingestion pipeline 448756e5-55bb-45fc-9490-c12c0ef6ed90 on key dcm25/vpu0-0a/full/2021-05-30_18-39-37.938493997_87_926.073563053
# launched image ingestion pipeline aa066caa-2032-45c7-868e-c90f3f2e83d0 on key dcm25/vpu0-0a/full/2021-05-27_20-05-11.103989415_81_1207.323231751
# launched image ingestion pipeline 897fd91d-967b-4ac4-a114-5da5fdfa4692 on key dcm25/vpu0-0a/full/2021-05-20_20-06-36.956335999_47_362.217381119

# %%
lr= sorted(np.unique(vpus))
mr = sorted(vpus)
print(lr[0])
print(mr[0])

print(mr == lr)
# Out:
# db2/vpu0-10a/full/2021-06-09_18-12-42.454382431_443_6052.370048027
# db2/vpu0-10a/full/2021-06-09_18-12-42.454382431_443_6052.370048027
# True

# %%
robot_name = 'db8'
in_s3 = [v for v in db8_in_s3  if (v.split(robot_name)[1][0:8] != '/vpu0-0a')]
    # omit anthing but full logs
in_s3 = [v for v in in_s3  if len(v.split('full'))>1]
in_s3 = set([d.split('/log')[0] for d in in_s3])
print(len(in_s3))
list(in_s3)[10:20]
# Out:
# 228
# ['db8/vpu0-2a/full/2021-06-09_20-39-21.317797596_359_764.712383189',
#  'db8/vpu0-14a/full/2021-06-10_15-59-25.134464136_281_11706.818771931',
#  'db8/vpu0-3a/full/2021-06-10_15-59-05.875493610_343_11687.338647656',
#  'db8/vpu0-14a/full/2021-06-10_15-58-57.398867230_281_11679.083174993',
#  'db8/vpu0-13a/full/2021-06-11_14-56-27.545658460_373_2393.529725240',
#  'db8/vpu0-1a/full/2021-06-10_16-32-26.883237997_361_13688.579352407',
#  'db8/vpu0-11a/full/2021-06-11_14-56-59.433583804_374_2425.661908635',
#  'db8/vpu0-14a/full/2021-06-11_14-46-14.245065688_286_1780.507646301',
#  'db8/vpu0-12a/full/2021-06-10_15-54-27.629244018_364_11409.007836013',
#  'db8/vpu0-13a/full/2021-06-10_14-08-33.026096031_368_5054.520648780']

# %%
for i in list(in_s3):
    submit_image_ingestion_workflow('brt-dcm-data', i)
    time.sleep(30)
# Out:
# launched image ingestion pipeline 71400bf8-7980-43f7-bac0-02d4e698385e on key db8/vpu0-1a/full/2021-06-11_14-48-04.276660442_366_1853.561335462
# launched image ingestion pipeline 657cd0b4-22db-4061-9750-375a16feef40 on key db8/vpu0-10a/full/2021-06-10_14-06-33.727684440_383_4935.345559932
# launched image ingestion pipeline 3d33d8c1-0a02-4efc-9966-44654f89e46a on key db8/vpu0-12a/full/2021-06-10_15-59-05.890441111_364_11687.269032850
# launched image ingestion pipeline 70fade3e-1b15-416d-a6c2-565e927f5995 on key db8/vpu0-12a/full/2021-06-11_14-36-15.789576550_369_1181.731651484
# launched image ingestion pipeline 4c67dc9f-ee00-4fed-b1d1-014f2bdf0d16 on key db8/vpu0-11a/full/2021-06-10_14-08-33.034139113_370_5054.784347962
# launched image ingestion pipeline dcfcb61d-efeb-4d78-81ee-e020c9352220 on key db8/vpu0-1a/full/2021-06-11_14-56-27.517447561_366_2356.802122741
# launched image ingestion pipeline 15872d28-0121-406d-8040-a515b84b7b96 on key db8/vpu0-1a/full/2021-06-11_14-36-15.837744995_366_1145.122419983
# launched image ingestion pipeline b1ed86db-5d1a-42d1-8403-c602869b263a on key db8/vpu0-3a/full/2021-06-10_16-27-38.862906456_343_13400.326060406
# launched image ingestion pipeline 0c16fff5-f09f-45da-b6f2-d2f59a203c49 on key db8/vpu0-2a/full/2021-06-10_14-06-33.721411533_362_4935.134572501
# launched image ingestion pipeline 956ae923-8f2a-42f1-be73-9bf645a9154e on key db8/vpu0-4a/full/2021-06-11_14-56-59.409154569_365_2388.395536403
# launched image ingestion pipeline a094498b-601e-401a-9533-64bb1cb5e531 on key db8/vpu0-2a/full/2021-06-09_20-39-21.317797596_359_764.712383189
# launched image ingestion pipeline b0750f4d-4237-47db-86b5-5ff6401edc5c on key db8/vpu0-14a/full/2021-06-10_15-59-25.134464136_281_11706.818771931
# launched image ingestion pipeline 3380fc91-cdb2-47d0-9260-6109ac09cdbf on key db8/vpu0-3a/full/2021-06-10_15-59-05.875493610_343_11687.338647656
# launched image ingestion pipeline b96f993f-42c8-442e-a544-28e35e86bca7 on key db8/vpu0-14a/full/2021-06-10_15-58-57.398867230_281_11679.083174993
# launched image ingestion pipeline f648bc60-2e19-4666-bf7b-c8556b9e8038 on key db8/vpu0-13a/full/2021-06-11_14-56-27.545658460_373_2393.529725240
# launched image ingestion pipeline 1beb28e7-4dff-4b72-b2ed-3fa1ff37a70d on key db8/vpu0-1a/full/2021-06-10_16-32-26.883237997_361_13688.579352407
# launched image ingestion pipeline 6b383537-266a-4a6a-9f36-16b8d29978f4 on key db8/vpu0-11a/full/2021-06-11_14-56-59.433583804_374_2425.661908635
# launched image ingestion pipeline e78f5e83-07dc-4885-97e1-a1b18277ea7f on key db8/vpu0-14a/full/2021-06-11_14-46-14.245065688_286_1780.507646301
# launched image ingestion pipeline 554a81da-2668-4254-b6db-745683bf64cd on key db8/vpu0-12a/full/2021-06-10_15-54-27.629244018_364_11409.007836013
# launched image ingestion pipeline 21bb7cdc-1b2f-4119-b4a7-511ec78ff24e on key db8/vpu0-13a/full/2021-06-10_14-08-33.026096031_368_5054.520648780
# launched image ingestion pipeline fddb8ebc-0d8c-48cb-a4a4-59aae926d83f on key db8/vpu0-3a/full/2021-06-09_16-29-51.401274136_338_6766.467979553
# launched image ingestion pipeline e6a379f4-5f7c-466b-880f-9ab63ef0599a on key db8/vpu0-14a/full/2021-06-11_14-36-15.821359945_286_1182.083940654
# launched image ingestion pipeline 4c055d0b-1abb-4cbc-9b5e-46b3f8436543 on key db8/vpu0-2a/full/2021-06-11_14-46-14.250587285_367_1743.203083216
# launched image ingestion pipeline 91a5f681-c60e-4d7b-86dc-8febe8d53f9b on key db8/vpu0-13a/full/2021-06-10_14-06-33.715186434_368_4935.209739183
# launched image ingestion pipeline ce4ebbfd-8b89-4100-8f07-e1f266c011a5 on key db8/vpu0-4a/full/2021-06-10_15-58-57.377279029_360_11678.809253166
# launched image ingestion pipeline a4e1bb27-dc92-42c3-afac-085b2dc48d05 on key db8/vpu0-10a/full/2021-06-10_14-06-47.550824077_383_4949.168700369
# launched image ingestion pipeline 7ebabc66-c25b-49fa-a3e4-385754435a0f on key db8/vpu0-1a/full/2021-06-10_14-08-33.029909151_361_5054.725455915
# launched image ingestion pipeline 0a9a38cf-1bf8-48ce-bef6-a219b789e17c on key db8/vpu0-12a/full/2021-06-11_14-46-14.239903617_369_1780.181978711
# launched image ingestion pipeline fd0f023c-d0da-4b78-a6f0-c333b7eae86c on key db8/vpu0-1a/full/2021-06-10_16-27-38.859287845_361_13400.555402511
# launched image ingestion pipeline 8d0df056-54f5-4e4a-a784-bf5f7b15a914 on key db8/vpu0-14a/full/2021-06-09_15-19-15.875628134_276_2531.197810159
# launched image ingestion pipeline bab6f7f9-9269-4c03-968c-73ad6fda2331 on key db8/vpu0-10a/full/2021-06-10_15-54-47.662897988_383_11429.281439720
# launched image ingestion pipeline f605c7e7-32df-4fda-828f-70813b04a0f4 on key db8/vpu0-11a/full/2021-06-10_14-06-49.481768728_370_4951.231979593
# launched image ingestion pipeline 47ba3388-e541-42af-98e7-6f51ea5dc514 on key db8/vpu0-2a/full/2021-06-11_14-56-27.534363145_367_2356.486859172
# launched image ingestion pipeline fc93a0c5-4692-4b92-8750-472918b0b7a0 on key db8/vpu0-4a/full/2021-06-10_15-59-05.886059109_360_11687.318033150
# launched image ingestion pipeline cccf5d85-0203-4279-8523-80f5394a5b3e on key db8/vpu0-3a/full/2021-06-10_15-59-25.121109448_343_11706.584263654
# launched image ingestion pipeline 20471c10-5143-4402-b437-7e027c8caf55 on key db8/vpu0-2a/full/2021-06-11_14-31-57.734151253_367_886.686647280
# launched image ingestion pipeline 701cd04f-c226-4416-8cae-b57d963d6461 on key db8/vpu0-3a/full/2021-06-10_14-08-46.798111086_343_5068.258808519
# launched image ingestion pipeline c348b048-c355-48e7-96ff-0da4784f6252 on key db8/vpu0-11a/full/2021-06-10_15-58-57.402817155_370_11679.148783328
# launched image ingestion pipeline 73a64ff3-31d3-4ca1-8a7c-1d568eae6219 on key db8/vpu0-13a/full/2021-06-10_15-54-27.633068794_368_11409.127243389
# launched image ingestion pipeline 7ff744a0-f0d3-44bb-b68c-6c67c3b2521a on key db8/vpu0-1a/full/2021-06-09_20-39-21.315495499_358_765.020279394
# launched image ingestion pipeline 766accbb-5745-447a-a4cb-3008eb70a8a6 on key db8/vpu0-14a/full/2021-06-10_16-32-26.879188423_281_13688.563496250
# launched image ingestion pipeline ba16b752-d4f5-48cb-8d8d-bcae0ef3aae8 on key db8/vpu0-2a/full/2021-06-10_14-08-33.007597426_362_5054.420758394
# launched image ingestion pipeline 516faf41-d41f-4829-90ba-410a99357537 on key db8/vpu0-11a/full/2021-06-09_20-39-21.327112485_367_765.123571523
# launched image ingestion pipeline c1cb3a81-56e6-4332-a919-a0e157a46b19 on key db8/vpu0-14a/full/2021-06-10_16-27-38.856323550_281_13400.540631441
# launched image ingestion pipeline afd811b6-4dc5-4219-afe9-4bbc3f2cbe22 on key db8/vpu0-11a/full/2021-06-10_16-27-38.860991939_370_13400.606957951
# launched image ingestion pipeline 627cc8ee-adc2-4b9d-9b62-383b55ca0b6e on key db8/vpu0-11a/full/2021-06-10_15-54-27.613729140_370_11409.359695345
# launched image ingestion pipeline 1f4ccf1b-6a56-429d-943d-dd1ee55daf17 on key db8/vpu0-11a/full/2021-06-10_15-59-15.463441249_370_11697.209407582
# launched image ingestion pipeline 670249a1-23ee-44a8-a958-1c17285a9f77 on key db8/vpu0-10a/full/2021-06-09_16-05-05.588951763_378_5280.811987395
# launched image ingestion pipeline abbb4c7c-c228-4c4f-a336-23aedde39827 on key db8/vpu0-3a/full/2021-06-09_15-19-15.887186945_338_2530.953892362
# launched image ingestion pipeline 311e07ba-5fc8-41f8-aba6-88900fa7572a on key db8/vpu0-2a/full/2021-06-10_15-54-27.637124278_362_11409.045456987
# launched image ingestion pipeline 235a16ab-b7fe-424c-aee6-2e9c8b54a5d9 on key db8/vpu0-13a/full/2021-06-09_16-05-05.595176408_363_5280.801960754
# launched image ingestion pipeline 8bb2c965-d9f3-4c10-b4c9-09e329256015 on key db8/vpu0-3a/full/2021-06-10_15-58-57.376018924_343_11678.839173162
# launched image ingestion pipeline a7e0d93d-53c9-41b1-99c5-e7583e10bbaf on key db8/vpu0-14a/full/2021-06-11_14-37-51.080665457_286_1277.343246070
# launched image ingestion pipeline 6bcf9987-a227-4e48-9b1f-1cdb6e0d11b9 on key db8/vpu0-14a/full/2021-06-10_15-59-15.465387568_281_11697.149695331
# launched image ingestion pipeline c7def6ae-5695-4824-a27d-17b6f8a105f9 on key db8/vpu0-3a/full/2021-06-10_15-54-27.619908315_343_11409.083062489
# launched image ingestion pipeline 92216fce-d177-4c50-9afb-2f7f53a80703 on key db8/vpu0-3a/full/2021-06-11_14-37-51.066116676_347_1240.122715591
# launched image ingestion pipeline 707775b6-faee-41fa-97d4-3c3a29a261bd on key db8/vpu0-3a/full/2021-06-10_16-32-26.886957300_343_13688.350111506
# launched image ingestion pipeline 085b033f-9529-43ce-8907-a284014072e0 on key db8/vpu0-4a/full/2021-06-10_16-32-26.889328154_360_13688.321302291
# launched image ingestion pipeline 4a07860c-45fb-4064-a4c1-4f72f82c0f81 on key db8/vpu0-2a/full/2021-06-10_15-59-25.118611128_362_11706.526943645
# launched image ingestion pipeline 466c48ff-9b1d-44f9-9e77-53102c652ae7 on key db8/vpu0-11a/full/2021-06-11_14-56-27.527643170_374_2393.755989475
# launched image ingestion pipeline e9c3c64f-db4d-46a1-abc0-df9d06751b8a on key db8/vpu0-14a/full/2021-06-10_15-54-27.606464977_281_11409.290772484
# launched image ingestion pipeline 4bac6bdf-7764-4fb6-abd6-1f95b2d84747 on key db8/vpu0-12a/full/2021-06-09_14-53-39.594263728_359_994.537258544
# launched image ingestion pipeline e70ca503-9a1b-45d1-90e0-4ef316e6ba9c on key db8/vpu0-10a/full/2021-06-10_16-27-38.872770418_383_13400.491312278
# launched image ingestion pipeline 9727ae69-2f43-47eb-b8d6-adfa43aba3a6 on key db8/vpu0-11a/full/2021-06-09_16-05-05.598498985_365_5280.908678366
# launched image ingestion pipeline a8937904-6257-4e61-a6ff-221c34242ce5 on key db8/vpu0-3a/full/2021-06-11_14-56-59.430121287_347_2388.486720042
# launched image ingestion pipeline d4c49b1a-377a-4531-939b-a2c4edc9137d on key db8/vpu0-10a/full/2021-06-09_15-21-05.406593204_378_2640.629628548
# launched image ingestion pipeline 6c623337-3738-4093-8c0a-bf099c7ae5aa on key db8/vpu0-14a/full/2021-06-11_14-56-27.530113750_286_2393.792694331
# launched image ingestion pipeline a9987000-f475-4cc2-971c-3b9a2407436f on key db8/vpu0-4a/full/2021-06-11_14-36-15.827356369_365_1144.813738235
# launched image ingestion pipeline 6d5cdf47-aae5-4ed7-9117-9d12d911380f on key db8/vpu0-1a/full/2021-06-09_16-05-05.617146897_356_5280.922557920
# launched image ingestion pipeline cf5493fd-5284-4ea7-8153-c9b6ff4cdfb5 on key db8/vpu0-14a/full/2021-06-09_14-53-39.596765368_276_994.918947265
# launched image ingestion pipeline 13eeea51-3247-411a-986b-59a5fe7c340d on key db8/vpu0-3a/full/2021-06-09_14-53-39.603357864_338_994.670063377
# launched image ingestion pipeline db3d9a3f-7a0e-42af-bffc-da848fefd274 on key db8/vpu0-14a/full/2021-06-10_16-34-10.288993677_281_13791.973302208
# launched image ingestion pipeline 250cc70f-45e8-4e42-8f0e-d20b082752e8 on key db8/vpu0-11a/full/2021-06-11_14-31-57.771403460_374_923.999749797
# launched image ingestion pipeline eea91a35-594f-4085-970e-99b6f89988c1 on key db8/vpu0-14a/full/2021-06-09_16-05-05.601959099_276_5280.924141156
# launched image ingestion pipeline a20d33e4-7672-4594-b674-b6edec5102df on key db8/vpu0-1a/full/2021-06-11_14-31-57.759981651_366_887.044656575
# launched image ingestion pipeline e4e7dc32-a751-4f50-8447-867ee3095633 on key db8/vpu0-4a/full/2021-06-11_14-37-51.068472902_365_1240.054854768
# launched image ingestion pipeline a43e8486-c771-417a-924d-b53849fab13d on key db8/vpu0-10a/full/2021-06-09_14-53-39.605126327_378_994.828162119
# launched image ingestion pipeline 382406b0-249a-4c0c-8be9-2bd72e809659 on key db8/vpu0-4a/full/2021-06-10_14-13-23.645719350_360_5345.076911860
# launched image ingestion pipeline e0688e3c-341a-484e-a104-f09cb602b3c3 on key db8/vpu0-4a/full/2021-06-10_14-08-33.012972780_360_5054.444165322
# launched image ingestion pipeline e6b12c3b-32f7-4d8d-a99e-cfb88816c012 on key db8/vpu0-2a/full/2021-06-11_14-37-51.091474188_367_1240.043970183
# launched image ingestion pipeline 67a4f9f9-bb02-40dd-810b-d2e6dfecd280 on key db8/vpu0-1a/full/2021-06-09_15-19-15.883782437_356_2531.189193332
# launched image ingestion pipeline 3b67971f-a040-4bda-8e32-f589d3d8654e on key db8/vpu0-14a/full/2021-06-10_14-06-33.737526894_281_4935.420798720
# launched image ingestion pipeline e098815b-fcbf-44d2-aae4-e7dc6cd8bb8c on key db8/vpu0-14a/full/2021-06-11_14-31-57.729028752_286_923.991609493
# launched image ingestion pipeline dd9e76df-0a4e-4dac-a271-e1eb749e7b27 on key db8/vpu0-10a/full/2021-06-10_14-08-33.015466101_383_5054.633341081
# launched image ingestion pipeline 13386a8b-66bb-40c1-83f0-bbc84555f433 on key db8/vpu0-12a/full/2021-06-10_14-06-33.730513373_364_4935.114351385
# launched image ingestion pipeline 2887d58b-10db-494f-adea-ddefcb3f0d21 on key db8/vpu0-1a/full/2021-06-09_16-29-51.409563903_356_6766.714974958
# launched image ingestion pipeline 769a50bb-d6b1-418a-be99-a7f0fdce4a3a on key db8/vpu0-14a/full/2021-06-09_16-29-51.406451628_276_6766.728633365
# launched image ingestion pipeline 5aad8459-a173-4240-a340-8d53ad3259bb on key db8/vpu0-13a/full/2021-06-09_15-19-15.885928376_363_2531.092712562
# launched image ingestion pipeline 89f08f57-502f-4e1e-b664-82feaef650e2 on key db8/vpu0-10a/full/2021-06-11_14-56-27.541217165_388_2393.690928245
# launched image ingestion pipeline fa89f0bb-5b0e-4ff7-a69a-2acc44da7509 on key db8/vpu0-11a/full/2021-06-10_15-59-25.132216327_370_11706.878182692
# launched image ingestion pipeline 2a1717bf-e707-4446-b9f4-8e23565c5a04 on key db8/vpu0-13a/full/2021-06-11_14-46-14.242124177_373_1780.226190925
# launched image ingestion pipeline f7a2c4f4-9650-41e8-b0c2-dba01581af80 on key db8/vpu0-1a/full/2021-06-11_14-46-14.258678178_366_1743.543353102
# launched image ingestion pipeline e137f95a-9d48-48d7-a0fd-925e155945a5 on key db8/vpu0-1a/full/2021-06-11_14-56-59.427787855_366_2388.712462811
# launched image ingestion pipeline e6128589-66f5-46ab-bec4-489071d82bee on key db8/vpu0-1a/full/2021-06-10_14-15-28.263860553_361_5469.959407893
# launched image ingestion pipeline da5f3d49-5de1-4179-bbb9-ac2a4b59eadb on key db8/vpu0-3a/full/2021-06-10_14-13-23.643818659_343_5345.104515772
# launched image ingestion pipeline be9b71a9-2548-44e8-96c9-2a85e3f378d1 on key db8/vpu0-2a/full/2021-06-10_14-15-55.407324279_362_5496.820485759
# launched image ingestion pipeline 18e60f9d-b3b9-4503-98f6-0f2ebbb3c847 on key db8/vpu0-3a/full/2021-06-09_16-05-05.586419180_338_5280.653124565
# launched image ingestion pipeline 49349b10-6a96-4d7d-9d0f-c511a4fcdf8c on key db8/vpu0-2a/full/2021-06-10_16-32-26.913975742_362_13688.322308259
# launched image ingestion pipeline 5b754dec-4f45-45a9-a182-8bcc2b6300f3 on key db8/vpu0-12a/full/2021-06-09_16-29-51.419877452_359_6766.362872236
# launched image ingestion pipeline 384cbbe3-af5a-4f36-b4ac-b4eb68052c6d on key db8/vpu0-10a/full/2021-06-11_14-37-51.070914065_388_1277.220625049
# launched image ingestion pipeline 71a467af-01cb-4f75-b01c-4142cb685159 on key db8/vpu0-11a/full/2021-06-09_14-53-39.593557678_365_994.903737091
# launched image ingestion pipeline 286edefb-843d-4335-a4e5-dbcfd48948a8 on key db8/vpu0-2a/full/2021-06-11_14-48-04.288682370_367_1853.241178077
# launched image ingestion pipeline 2f75504b-4161-41f7-88ee-130daebe98b5 on key db8/vpu0-14a/full/2021-06-09_20-39-21.305335495_278_764.982966935
# launched image ingestion pipeline e2c75ad5-de22-43aa-86a7-433eadeb8bf2 on key db8/vpu0-12a/full/2021-06-10_15-59-15.448426233_364_11696.827000147
# launched image ingestion pipeline 59337258-5973-40e8-ab5c-9f578530290d on key db8/vpu0-11a/full/2021-06-10_14-06-33.734426479_370_4935.484635296
# launched image ingestion pipeline 4ac3f21e-0496-4fa8-8f25-e79325ab684a on key db8/vpu0-10a/full/2021-06-09_15-19-15.888731801_378_2531.111767433
# launched image ingestion pipeline dab75b88-86a7-46c0-9685-a86268e5d621 on key db8/vpu0-2a/full/2021-06-10_15-54-47.673162205_362_11429.081494882
# launched image ingestion pipeline b8663b0b-eb83-4451-b45a-32090e3145c4 on key db8/vpu0-1a/full/2021-06-10_15-54-47.653485680_361_11429.349600186
# launched image ingestion pipeline 17351d6b-5bc9-4d57-9a6a-961f51ff5104 on key db8/vpu0-2a/full/2021-06-10_15-58-57.393487511_362_11678.801820060
# launched image ingestion pipeline 0395ec57-8d55-48af-8bfa-7fb39231b1b5 on key db8/vpu0-13a/full/2021-06-09_15-21-05.403758466_363_2640.610542780
# launched image ingestion pipeline 0e1d2e32-46d7-40a5-9d5b-ea0d53083dbe on key db8/vpu0-13a/full/2021-06-09_14-53-39.608943871_363_994.811655512
# launched image ingestion pipeline 8dcadf5a-548d-4dc1-b9c5-1c07d967afa8 on key db8/vpu0-12a/full/2021-06-11_14-56-27.543327091_369_2393.485402025
# launched image ingestion pipeline 8bbee5f1-08a3-40ca-82a4-95c9bca7c083 on key db8/vpu0-13a/full/2021-06-11_14-37-51.078608044_373_1277.062674696
# launched image ingestion pipeline 0d145195-21cc-4e2d-9040-cfcc60a1aebb on key db8/vpu0-4a/full/2021-06-09_20-39-21.313708252_357_764.742951055
# launched image ingestion pipeline 15dd5a31-17e3-4d14-9444-95730da2eb38 on key db8/vpu0-4a/full/2021-06-10_15-59-25.123209116_360_11706.555183317
# launched image ingestion pipeline c1afe3af-d51a-4874-a29d-577997d88762 on key db8/vpu0-12a/full/2021-06-10_15-59-25.127874710_364_11706.506466769
# launched image ingestion pipeline 8d896381-d3ed-4331-a968-af63d2f39a44 on key db8/vpu0-13a/full/2021-06-10_16-32-26.909887488_368_13688.404061891
# launched image ingestion pipeline 151fe7d0-8389-45b9-825d-68a5fad981ae on key db8/vpu0-2a/full/2021-06-10_14-06-52.878824388_362_4954.291985836
# launched image ingestion pipeline 6a6948f9-186f-4daf-ad7b-1eb948604d36 on key db8/vpu0-2a/full/2021-06-09_16-29-51.413382760_357_6766.322532375
# launched image ingestion pipeline 1887735c-dd1a-4e38-9e5f-f0d8f571ba2f on key db8/vpu0-13a/full/2021-06-09_16-29-51.404958762_363_6766.611743172
# launched image ingestion pipeline 22eec7d8-3ffa-4b67-8eeb-ffa2ba78c329 on key db8/vpu0-11a/full/2021-06-11_14-46-14.270410720_374_1780.498756929
# launched image ingestion pipeline 65d40a50-98cb-4464-bd43-54b188e17f52 on key db8/vpu0-10a/full/2021-06-11_14-46-14.212633097_388_1780.362344209
# launched image ingestion pipeline 079b76a7-1eed-414f-bcc1-116770060493 on key db8/vpu0-4a/full/2021-06-10_15-54-27.622066302_360_11409.054040599
# launched image ingestion pipeline ba2d1a61-b82f-4d7d-9184-c6351b9214b6 on key db8/vpu0-13a/full/2021-06-10_15-59-15.450345320_368_11696.944519851
# launched image ingestion pipeline a79afdc9-cc90-4a69-afd8-26b61cbe95b6 on key db8/vpu0-11a/full/2021-06-10_15-54-47.657172723_370_11429.403138512
# launched image ingestion pipeline 3ab0b6cd-8d9d-468b-9d16-4d42aaef534f on key db8/vpu0-13a/full/2021-06-11_14-48-04.309779552_373_1890.293846492
# launched image ingestion pipeline cda6db3d-0be8-4f92-a33f-d8dca52e4e55 on key db8/vpu0-2a/full/2021-06-09_15-21-05.411496497_357_2640.320646016
# launched image ingestion pipeline cad6d41d-9e6f-420d-bdf4-f6fc2680d4b7 on key db8/vpu0-13a/full/2021-06-11_14-56-59.421056058_373_2425.405122870
# launched image ingestion pipeline 54ca363a-0ee7-43cb-9da0-e882014d22fb on key db8/vpu0-12a/full/2021-06-11_14-48-04.307670197_369_1890.249745323
# launched image ingestion pipeline 77f12ece-41c8-442b-8c7b-3a63911a8f06 on key db8/vpu0-10a/full/2021-06-09_20-39-21.315030365_380_764.992549834
# launched image ingestion pipeline 9c6ef139-20dd-489e-b707-f836758014d0 on key db8/vpu0-10a/full/2021-06-10_15-59-05.888204365_383_11687.506746161
# launched image ingestion pipeline 1f27f8bb-fe25-4992-8be5-86e1872f52ae on key db8/vpu0-4a/full/2021-06-09_15-19-15.867879019_355_2530.864520409
# launched image ingestion pipeline 3ae7ea6e-1ec0-4555-87a7-39198bc372b4 on key db8/vpu0-3a/full/2021-06-09_20-39-21.319334265_340_764.874042903
# launched image ingestion pipeline 545f5f49-145b-474e-94fa-94a080b15952 on key db8/vpu0-10a/full/2021-06-10_14-13-23.647681069_383_5345.265556561
# launched image ingestion pipeline d0376c74-ecfd-4435-8f7b-53b0ab2fd552 on key db8/vpu0-10a/full/2021-06-11_14-56-59.412914535_388_2425.562625487
# launched image ingestion pipeline a50bcd64-a3b9-4b95-bedc-8be24e784860 on key db8/vpu0-10a/full/2021-06-10_15-59-25.125549586_383_11706.744091190
# launched image ingestion pipeline 7dd2f759-9a01-482f-823d-587117e5b77e on key db8/vpu0-3a/full/2021-06-10_14-08-33.010281516_343_5054.470978437
# launched image ingestion pipeline 31e0a631-3a90-42b3-9bf5-97686db8b75b on key db8/vpu0-10a/full/2021-06-09_16-29-51.403170677_378_6766.626206661
# launched image ingestion pipeline 89749e5f-b63c-4d5c-8633-089dce5fc8f1 on key db8/vpu0-13a/full/2021-06-10_14-14-16.315617625_368_5397.810170854
# launched image ingestion pipeline e5df667d-f013-4d27-b3b5-71468060d8df on key db8/vpu0-2a/full/2021-06-10_16-27-38.900506114_362_13400.308838791
# launched image ingestion pipeline c4c2b060-4faf-42a0-9338-22b80846fd44 on key db8/vpu0-3a/full/2021-06-11_14-36-15.840340908_347_1144.896939695
# launched image ingestion pipeline d25dfab6-7ef0-4ab2-9951-cb9c8ca649e1 on key db8/vpu0-14a/full/2021-06-09_15-21-05.420639157_276_2640.742821182
# launched image ingestion pipeline f4cdcfab-ec29-4efa-9e37-7ca4577cc6fa on key db8/vpu0-2a/full/2021-06-10_14-07-56.193635330_362_5017.606796938
# launched image ingestion pipeline 7690b293-7d92-459a-918c-0e0f9b53ba39 on key db8/vpu0-10a/full/2021-06-10_15-58-57.379190080_383_11678.997731844
# launched image ingestion pipeline 748cb9b4-0417-4e35-ad25-02423221c847 on key db8/vpu0-12a/full/2021-06-09_20-39-21.330521116_361_764.826418875
# launched image ingestion pipeline 65cb4ff6-51df-4d9f-8b28-59ff4529fb17 on key db8/vpu0-3a/full/2021-06-10_15-54-47.675290907_343_11429.138445145
# launched image ingestion pipeline 2a062692-07bd-4537-b17a-b3208e2b8902 on key db8/vpu0-12a/full/2021-06-11_14-37-51.072823060_369_1277.014866184
# launched image ingestion pipeline f9cd2d5e-d898-49f3-993e-a0c5f2839c20 on key db8/vpu0-2a/full/2021-06-10_15-59-05.872964565_362_11687.281297018
# launched image ingestion pipeline 95f96f85-ce9d-4536-b906-b1ee5eb66a70 on key db8/vpu0-11a/full/2021-06-09_16-29-51.417130839_365_6766.727310124
# launched image ingestion pipeline b35c1a90-fac4-4560-9b4b-7c2fecf6232e on key db8/vpu0-1a/full/2021-06-10_15-59-15.461358893_361_11697.157473463
# launched image ingestion pipeline f0cf1879-00bf-49f6-9975-d48a9f575266 on key db8/vpu0-3a/full/2021-06-11_14-56-27.525299873_347_2356.581898788
# launched image ingestion pipeline cb531c74-2f7a-44ca-8719-d3a58b482f17 on key db8/vpu0-4a/full/2021-06-09_15-21-05.414563277_355_2640.411204603
# launched image ingestion pipeline 7ff67237-0704-481d-888f-b5d9f713b65c on key db8/vpu0-13a/full/2021-06-11_14-31-57.727013952_373_923.711080892
# launched image ingestion pipeline 315f3b1b-2028-428d-b3be-61d9e5fce02c on key db8/vpu0-2a/full/2021-06-09_15-19-15.866253862_357_2530.775403285
# launched image ingestion pipeline 1bd11c77-108e-40c5-a3c0-7f31d1c35b75 on key db8/vpu0-11a/full/2021-06-11_14-37-51.061748060_374_1277.290094237
# launched image ingestion pipeline 5416a403-af9a-48f0-b6a1-cda9e7537ca9 on key db8/vpu0-12a/full/2021-06-11_14-31-57.757659190_369_923.699734284
# launched image ingestion pipeline cd9df99b-1647-4ebc-b340-c9c4c0a7e51c on key db8/vpu0-13a/full/2021-06-10_15-59-05.868782069_368_11687.362956760
# launched image ingestion pipeline 87f56ade-26a6-4ab5-b21c-0099c6797d5d on key db8/vpu0-12a/full/2021-06-10_16-32-26.908027268_364_13688.286619359
# launched image ingestion pipeline 34701bb3-a7ab-4957-8b57-ac39d96472a3 on key db8/vpu0-3a/full/2021-06-10_15-59-15.457375139_343_11696.920529313
# launched image ingestion pipeline 279b3847-2905-4b13-a5ec-2b5a9c8ab7c2 on key db8/vpu0-3a/full/2021-06-10_14-07-50.146416370_343_5011.607113867
# launched image ingestion pipeline f7810fd8-fed8-4bb1-979a-ad1e74dd7541 on key db8/vpu0-12a/full/2021-06-09_16-05-05.600398660_359_5280.543393572
# launched image ingestion pipeline eb37e20b-beb7-4f80-9d89-5a0fa049b6d8 on key db8/vpu0-12a/full/2021-06-11_14-56-59.415542949_369_2425.357617723
# launched image ingestion pipeline 5f5251f1-9ed9-4ece-a2b2-4aa115252f05 on key db8/vpu0-3a/full/2021-06-11_14-48-04.280135042_347_1853.336733829
# launched image ingestion pipeline 37fd5789-3842-48b0-9736-53b27c65afe4 on key db8/vpu0-4a/full/2021-06-10_15-59-15.459592302_360_11696.891566471
# launched image ingestion pipeline 59f3d14e-b379-41a2-82a0-d4e51296415d on key db8/vpu0-14a/full/2021-06-10_15-54-47.660337123_281_11429.344644854
# launched image ingestion pipeline 27daa61d-ccb2-414d-8c4e-55f25c5d3d79 on key db8/vpu0-4a/full/2021-06-09_16-05-05.597272153_355_5280.593913415
# launched image ingestion pipeline 8d4eef83-2608-4813-989b-501d7841d8e1 on key db8/vpu0-3a/full/2021-06-10_14-06-33.723619683_343_4935.184316412
# launched image ingestion pipeline 2024c49e-76e0-4bcc-a977-f65457625959 on key db8/vpu0-10a/full/2021-06-11_14-31-57.751409824_388_923.901121064
# launched image ingestion pipeline 05ca1cdb-ba0b-4459-b63b-48d7098a813b on key db8/vpu0-1a/full/2021-06-09_14-53-39.599059014_356_994.904470069
# launched image ingestion pipeline ffcdc51d-b589-4457-89ab-454014ee14c8 on key db8/vpu0-13a/full/2021-06-10_15-59-25.096233473_368_11706.590407940
# launched image ingestion pipeline ed52ee55-f7a2-4536-9397-16a85e47a2b4 on key db8/vpu0-1a/full/2021-06-10_15-54-27.608825599_361_11409.304940201
# launched image ingestion pipeline cc20f823-e2ae-4cac-a5ed-d2b47bc2195d on key db8/vpu0-4a/full/2021-06-11_14-31-57.746297153_365_886.732679179
# launched image ingestion pipeline 25eecea4-6dd3-4d2c-b8af-a327d9d64591 on key db8/vpu0-3a/full/2021-06-11_14-46-14.265842416_347_1743.322441331
# launched image ingestion pipeline 43ec494c-d294-40a2-99ba-93439c17f1ae on key db8/vpu0-2a/full/2021-06-10_15-59-15.453712517_362_11696.862045194
# launched image ingestion pipeline 60570fb3-1f61-48bc-a41b-8554cd75da5d on key db8/vpu0-13a/full/2021-06-11_14-36-15.812477755_373_1181.796544343
# launched image ingestion pipeline 92f074b6-dc57-48b0-a7f0-fe699fc3ffe2 on key db8/vpu0-2a/full/2021-06-09_16-05-05.619071283_357_5280.528220866
# launched image ingestion pipeline 7143020b-7c4e-4959-954d-54ac229f839e on key db8/vpu0-4a/full/2021-06-09_14-53-39.590941385_355_994.587582775
# launched image ingestion pipeline 9fc86ae9-8da4-4f56-aa73-9adb47044d96 on key db8/vpu0-1a/full/2021-06-10_14-06-33.732607955_361_4935.428154559
# launched image ingestion pipeline 7de34ddf-426c-4c93-8cf1-451ec8a04f4f on key db8/vpu0-11a/full/2021-06-10_16-32-26.885077543_370_13688.631043620
# launched image ingestion pipeline b809f3b6-895d-4885-8b7e-f7c60e5dd997 on key db8/vpu0-14a/full/2021-06-11_14-56-59.425608419_286_2425.688189096
# launched image ingestion pipeline 971f02bf-92d6-49a6-b682-35027e51687a on key db8/vpu0-13a/full/2021-06-10_15-58-57.385359904_368_11678.879534531
# launched image ingestion pipeline 45a0f78b-1803-4e97-ab82-0101607906ab on key db8/vpu0-12a/full/2021-06-10_14-08-33.020254492_364_5054.404092472
# launched image ingestion pipeline 91fa2c7d-86f3-4564-baa0-40d66a2d7858 on key db8/vpu0-1a/full/2021-06-10_15-58-57.401291530_361_11679.097405940
# launched image ingestion pipeline 199d2280-5673-473b-9305-628fff7eb669 on key db8/vpu0-14a/full/2021-06-10_14-08-33.039980988_281_5054.723252782
# launched image ingestion pipeline 0d98bca7-79e1-4067-9ca5-89188ccdda1e on key db8/vpu0-11a/full/2021-06-10_14-13-23.641631816_370_5345.391840633
# launched image ingestion pipeline 13b3b6ac-387a-4ccf-9d27-401c964e7a84 on key db8/vpu0-13a/full/2021-06-10_15-54-47.669800416_368_11429.163975139
# launched image ingestion pipeline a4443d44-b81c-4ee4-97d6-bf2bd8a61a70 on key db8/vpu0-12a/full/2021-06-10_16-30-07.539229680_364_13548.917822443
# launched image ingestion pipeline 4afae0b8-938f-4295-8085-07cfadc75b6a on key db8/vpu0-13a/full/2021-06-09_20-39-21.316562973_365_764.891139081
# launched image ingestion pipeline d7ff1a41-f9df-45fc-8ba8-4d76591259a6 on key db8/vpu0-12a/full/2021-06-10_16-27-38.874985914_364_13400.253578037
# launched image ingestion pipeline eabdfebc-3b17-4ade-be56-e030582fa2a5 on key db8/vpu0-10a/full/2021-06-11_14-48-04.305341760_388_1890.455052872
# launched image ingestion pipeline c20a1e9e-25c2-4ac7-8bb6-51aee9cd4d19 on key db8/vpu0-13a/full/2021-06-10_14-13-23.651740322_368_5345.146292943
# launched image ingestion pipeline f2547c1f-e1a9-458c-b004-33ee71832818 on key db8/vpu0-13a/full/2021-06-10_16-27-38.877030230_368_13400.371204953
# launched image ingestion pipeline 59fb23b1-cb00-4037-9653-a5304e1761df on key db8/vpu0-12a/full/2021-06-10_15-54-47.667952154_364_11429.046544245
# launched image ingestion pipeline c3f714ed-dd03-4e3b-8c65-fb200f04f0d6 on key db8/vpu0-4a/full/2021-06-10_16-27-38.870852975_360_13400.302827208
# launched image ingestion pipeline e5321b46-746c-46e7-8e04-61b2a47c6011 on key db8/vpu0-4a/full/2021-06-09_16-29-51.414956826_355_6766.411598120
# launched image ingestion pipeline 8cc21443-658e-464f-965b-fb905fe3c565 on key db8/vpu0-12a/full/2021-06-10_14-13-23.649731247_364_5345.033569419
# launched image ingestion pipeline 63d7eda3-748f-4a64-9fe1-6d84d7b649d9 on key db8/vpu0-4a/full/2021-06-10_14-06-33.725959716_360_4935.157152290
# launched image ingestion pipeline 13163f5a-f521-4ce2-84bd-eed9df532228 on key db8/vpu0-11a/full/2021-06-09_15-21-05.416339625_365_2640.726518814
# launched image ingestion pipeline 2f4cf591-36c6-4bb6-aa6b-50b3886b1082 on key db8/vpu0-11a/full/2021-06-10_15-59-05.925777984_370_11687.671744061
# launched image ingestion pipeline 0df47274-f309-4854-bc7e-12bcc231e021 on key db8/vpu0-2a/full/2021-06-10_14-13-23.655200051_362_5345.068361019
# launched image ingestion pipeline 7a177a00-cb0f-4b1e-8c57-b1be3b8e9a04 on key db8/vpu0-14a/full/2021-06-10_15-59-05.927548373_281_11687.611856168
# launched image ingestion pipeline bb0f0436-01a4-41c4-9978-c5d93481573c on key db8/vpu0-4a/full/2021-06-11_14-46-14.253352006_365_1743.239734096
# launched image ingestion pipeline 41065b55-4034-4a13-90ad-4b99f01f7c58 on key db8/vpu0-14a/full/2021-06-11_14-48-04.311875456_286_1890.574456069
# launched image ingestion pipeline b933e9b9-46f0-4e58-b14e-865c109522c1 on key db8/vpu0-3a/full/2021-06-09_15-21-05.405137170_338_2640.471842395
# launched image ingestion pipeline 6f6256e1-f6ab-4a52-b773-8b371ba57876 on key db8/vpu0-14a/full/2021-06-10_14-13-23.635921754_281_5345.319193516
# launched image ingestion pipeline e6ac6cdb-336d-4ea8-a059-bc4d382da0e4 on key db8/vpu0-1a/full/2021-06-09_15-21-05.423198984_356_2640.728610199
# launched image ingestion pipeline 3a54bb03-6f19-447c-b78d-26bb374b3560 on key db8/vpu0-11a/full/2021-06-11_14-36-15.842494592_374_1182.070840705
# launched image ingestion pipeline c9f1ee91-702a-4d3b-9688-d1e800d1a538 on key db8/vpu0-12a/full/2021-06-09_15-19-15.874199169_359_2530.817193921
# launched image ingestion pipeline d89133ab-a9cb-4805-86ea-3024ed67f963 on key db8/vpu0-1a/full/2021-06-10_15-59-05.923276630_361_11687.619391072
# launched image ingestion pipeline f64572dd-c678-43de-a1dd-f1923157c26c on key db8/vpu0-10a/full/2021-06-10_15-54-27.626681554_383_11409.245223414
# launched image ingestion pipeline a06e252e-a1bf-405f-8489-f86249100e6e on key db8/vpu0-4a/full/2021-06-11_14-56-27.539029579_365_2356.525411445
# launched image ingestion pipeline bf9d1d98-e3d3-4e5b-8dee-f88c90c9e84d on key db8/vpu0-4a/full/2021-06-10_15-54-47.677278407_360_11429.109252608
# launched image ingestion pipeline 45e528fa-f305-4a92-9e30-03397158bcf5 on key db8/vpu0-2a/full/2021-06-11_14-36-15.825677911_367_1144.778173874
# launched image ingestion pipeline c06909e6-d2a6-4931-b8a7-484ba68373d9 on key db8/vpu0-10a/full/2021-06-10_15-59-15.441309999_383_11697.059851795
# launched image ingestion pipeline 43d0a7b2-0651-479e-bb1a-5d6a5829bf9f on key db8/vpu0-12a/full/2021-06-09_15-21-05.419110833_359_2640.362105553
# launched image ingestion pipeline 3e78e09c-2c07-4a6e-a61f-713417f97992 on key db8/vpu0-10a/full/2021-06-11_14-36-15.829933608_388_1181.979644656
# launched image ingestion pipeline f4aa65ad-f155-409a-9ad1-bf86feddd754 on key db8/vpu0-3a/full/2021-06-11_14-31-57.767805248_347_886.824403555
# launched image ingestion pipeline a1d9f968-c648-480d-8b0d-1a5c146685c4 on key db8/vpu0-2a/full/2021-06-09_14-53-39.601999096_357_994.511148743
# launched image ingestion pipeline af57ba45-4945-4434-8519-32af6b6d831c on key db8/vpu0-1a/full/2021-06-11_14-37-51.064014982_366_1240.348689970
# launched image ingestion pipeline fb624838-b81e-45c6-b570-dd246a713264 on key db8/vpu0-4a/full/2021-06-11_14-48-04.303184801_365_1853.289566667
# launched image ingestion pipeline 299db1de-132c-4d0f-af8c-d1edb6023a59 on key db8/vpu0-2a/full/2021-06-11_14-56-59.405662333_367_2388.358158296
# launched image ingestion pipeline 4751f9b0-ee3d-4e8b-9301-53c3aa656bce on key db8/vpu0-11a/full/2021-06-09_15-19-15.871881078_365_2531.182060491
# launched image ingestion pipeline c7a277ca-d02e-403a-bd4a-38e45eb81ec4 on key db8/vpu0-11a/full/2021-06-11_14-48-04.281777211_374_1890.510123516
# launched image ingestion pipeline 61a927f1-0fec-4d70-858e-a118fccd025a on key db8/vpu0-10a/full/2021-06-10_16-32-26.902206508_383_13688.520748304
# launched image ingestion pipeline 4c57836f-2d24-4a25-8dd4-3f81db842f23 on key db8/vpu0-12a/full/2021-06-10_16-34-58.211833204_364_13839.590425743
# launched image ingestion pipeline 97f7235e-7a57-4e4c-89e6-db001baa3320 on key db8/vpu0-12a/full/2021-06-10_15-58-57.381463182_364_11678.760055113
# launched image ingestion pipeline 0fce1dfe-fc6c-4eaf-86e8-67426dfd19dd on key db8/vpu0-1a/full/2021-06-10_15-59-25.130110320_361_11706.826224890
# launched image ingestion pipeline c0df6cbc-6922-4623-b3a7-5b0a4cfad6fd on key db8/vpu0-1a/full/2021-06-10_14-13-23.638046510_361_5345.333593306

# %%
def submit_image_ingestion_workflow_db(bucket, s3_key, retry=50):
    """
    Wrapper around the brtdevkit image ingestion pipeline object that is error tolerant.
    :param bucket: S3 bucket name
    :param s3_key: s3 key of object to be processed
    :param retry: number of times to retry the worflow submission in case of failure
    :return: tuple of pipeline id and s3_key
    """

    global image_ingestion_pipeline  # NOQA. Use a global so we only have to set this var once and
                                     # can run tests importing this file without retrieving the pipeline.
                                     # TODO: Encapsulate in a class.
    if not image_ingestion_pipeline:
        image_ingestion_pipeline = KubeflowPipeline.retrieve(name=image_ingestion_pipeline_name)
    for i in range(retry):
        try:
            now = datetime.now().strftime("%d %B %Y %I:%M:%S %p")
            run = image_ingestion_pipeline.submit(
                job_name=f'Run of {image_ingestion_pipeline.name} at {now}',
                experiment_name=image_ingestion_experiment_name,
                params={
                    's3_bucket': bucket,
                    's3_key': s3_key,
                    'optional_args': '-u',
                    'optional_args': '-c0000'
                })
        except Exception as e:
            print(f'Attempt {i+1}: error encountered while processing {s3_key}, retrying...')
            print(e)
            time.sleep(5)
            continue
        break
    run_id = run['id']
    print(f"launched image ingestion pipeline {run_id} on key {s3_key}")
    return run_id, s3_key

# %%
# These logs cannot be ingested because of errors (jobs always fail with exit codes 134, 139)

bad_logs = ['dcm11/0/full/2021-04-12_20-11-21.560889820_117_457.700285692', 
           'dcm11/0/full/2021-04-12_20-20-15.207594838_117_991.346990646',
          'dcm13/0/full/2021-04-14_17-35-08.530899564_95_570.222910779',
           'dcm13/0/full/2021-04-06_19-48-18.536140039_68_1117.581160359',
        'dcm11/0/full/2021-04-12_20-20-15.207594838_117_991.346990646', 
        'dcm11/0/full/2021-04-12_20-11-21.560889820_117_457.700285692',
        'dcm13/0/full/2021-03-29_17-10-18.706782732_37_5593.882559140',
        'dcm11/0/full/2021-03-31_22-58-21.127151520_90_322.236384096'
          ]
